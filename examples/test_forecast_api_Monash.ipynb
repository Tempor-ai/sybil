# %% [markdown]
# ## TOC:
# * [Datasets](#datasets-bullet)
# * [Logging Settings](#logging-bullet)
# * [Request](#requests-bullet)
# * [Forecast](#forecast-bullet)
# * [Save Results](#results-bullet)

# %% [markdown]
# Additional to train api testing notebook features, this notebook contains
# - train test split for evaluation,
# - forecasting to see results,
# - metrics for forecasted period

# %%
import json
import yaml
import requests
import getpass
import os
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set()

# %% [markdown]
# ## Datasets <a class="anchor" id="datasets-bullet"></a>

# %% [markdown]
# ### Monash Datasets Extraction

# %%
from bs4 import BeautifulSoup
import zipfile
from datetime import datetime
from distutils.util import strtobool

# URL of the page containing the table
url = "https://forecastingdata.org/"

# Send a GET request to fetch the page content
response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')

# Locate the table containing the datasets
table = soup.find_all('table')[0]  # Assuming the first table is the target

# Extract table headers
headers = [th.text.strip() for th in table.find_all('th')]
headers.append('Download Links')

# Extract table rows
rows = []
for row in table.find_all('tr')[1:]:  # Skip the header row
    cols = [td.text.strip() for td in row.find_all('td')]
    download_links = [a['href'] for a in row.find_all('a', href=True)]
    cols.append(download_links)
    rows.append(cols)

# Create a pandas DataFrame
df = pd.DataFrame(rows, columns=headers)
df['Download'] = df["Download"].apply(lambda x: x.split('\n'))
df["Download Links"] = df["Download Links"].apply(lambda x: [l for l in x if 'zenodo' in l])
df = df.explode(["Download", "Download Links"]).reset_index()

def download_link_extract(url):
    try:
        # Send a GET request to the page
        response = requests.get(url)
        response.raise_for_status()  # Ensure we notice bad responses
    
        # Parse the HTML content using BeautifulSoup
        soup = BeautifulSoup(response.content, "html.parser")
    
        # Find all links on the page
        links = soup.find_all('a', href=True)
    
        # Look for the specific download link based on the "download=1" parameter
        download_link = None
        for link in links:
            if "download=1" in link['href']:
                download_link = link['href']
                break
    
        if download_link:
            return  'https://zenodo.org' + download_link
        else:
            return None
    except requests.exceptions.RequestException as e:
        print("An error occurred while making the request:", e)

df["download_link"] = df['Download Links'].apply(lambda x: download_link_extract(x))

def download_and_unzip(url, extract_to='.'):
    # Download the file from `url` and save it locally under `file_name`:
    local_zip_file = 'temp.zip'
    
    with requests.get(url, stream=True) as r:
        r.raise_for_status()
        with open(local_zip_file, 'wb') as f:
            for chunk in r.iter_content(chunk_size=8192):
                f.write(chunk)
    
    # Unzip the file
    with zipfile.ZipFile(local_zip_file, 'r') as zip_ref:
        zip_ref.extractall(extract_to)
    
    # Optionally remove the zip file after extraction
    os.remove(local_zip_file)

# %%
df[df['Domain'] == 'Economic']
# Out:
#     index  Dataset    Domain No: of Series Min. Length Max. Length  \
# 23      9  Bitcoin  Economic            18        2659        4581
# 24      9  Bitcoin  Economic            18        2659        4581
# 43     19  FRED-MD  Economic           107         728         728
#
#    Competition Multivariate     Download                  Source  \
# 23          No           No    W Missing           Curated by us
# 24          No           No  W/O Missing           Curated by us
# 43          No          Yes      Monthly  McCracken and Ng, 2016
#
#                        Download Links  \
# 23  https://zenodo.org/record/5121965
# 24  https://zenodo.org/record/5122101
# 43  https://zenodo.org/record/4654833
#
#                                         download_link
# 23  https://zenodo.org/records/5121965/files/bitco...
# 24  https://zenodo.org/records/5122101/files/bitco...
# 43  https://zenodo.org/records/4654833/files/fred_...

# %%
download_links = df[df['Domain'] == 'Economic']['download_link'].tolist()

# %%
for data_zip_path in download_links:
    download_and_unzip(data_zip_path, extract_to='./files')

# %%
def list_files(folder_path, file_format):
    # List all files in the given folder
    files = os.listdir(folder_path)
    # Filter out the files that end with .tsf
    tsf_files = [folder_path + '/' + f for f in files if f.endswith(file_format)]
    return tsf_files

# %%
files = list_files('./files', '.tsf')

# %%
files
# Out:
# ['./files/bitcoin_dataset_with_missing_values.tsf',
#  './files/bitcoin_dataset_without_missing_values.tsf',
#  './files/fred_md_dataset.tsf']

# %%
# Code snippet taking from https://github.com/rakshitha123/TSForecasting/blob/master/utils/data_loader.py

# Converts the contents in a .tsf file into a dataframe and returns it along with other meta-data of the dataset: frequency, horizon, whether the dataset contains missing values and whether the series have equal lengths
#
# Parameters
# full_file_path_and_name - complete .tsf file path
# replace_missing_vals_with - a term to indicate the missing values in series in the returning dataframe
# value_column_name - Any name that is preferred to have as the name of the column containing series values in the returning dataframe
def convert_tsf_to_dataframe(
    full_file_path_and_name,
    replace_missing_vals_with="NaN",
    value_column_name="series_value",
):
    col_names = []
    col_types = []
    all_data = {}
    line_count = 0
    frequency = None
    forecast_horizon = None
    contain_missing_values = None
    contain_equal_length = None
    found_data_tag = False
    found_data_section = False
    started_reading_data_section = False

    with open(full_file_path_and_name, "r", encoding="cp1252") as file:
        for line in file:
            # Strip white space from start/end of line
            line = line.strip()

            if line:
                if line.startswith("@"):  # Read meta-data
                    if not line.startswith("@data"):
                        line_content = line.split(" ")
                        if line.startswith("@attribute"):
                            if (
                                len(line_content) != 3
                            ):  # Attributes have both name and type
                                raise Exception("Invalid meta-data specification.")

                            col_names.append(line_content[1])
                            col_types.append(line_content[2])
                        else:
                            if (
                                len(line_content) != 2
                            ):  # Other meta-data have only values
                                raise Exception("Invalid meta-data specification.")

                            if line.startswith("@frequency"):
                                frequency = line_content[1]
                            elif line.startswith("@horizon"):
                                forecast_horizon = int(line_content[1])
                            elif line.startswith("@missing"):
                                contain_missing_values = bool(
                                    strtobool(line_content[1])
                                )
                            elif line.startswith("@equallength"):
                                contain_equal_length = bool(strtobool(line_content[1]))

                    else:
                        if len(col_names) == 0:
                            raise Exception(
                                "Missing attribute section. Attribute section must come before data."
                            )

                        found_data_tag = True
                elif not line.startswith("#"):
                    if len(col_names) == 0:
                        raise Exception(
                            "Missing attribute section. Attribute section must come before data."
                        )
                    elif not found_data_tag:
                        raise Exception("Missing @data tag.")
                    else:
                        if not started_reading_data_section:
                            started_reading_data_section = True
                            found_data_section = True
                            all_series = []

                            for col in col_names:
                                all_data[col] = []

                        full_info = line.split(":")

                        if len(full_info) != (len(col_names) + 1):
                            raise Exception("Missing attributes/values in series.")

                        series = full_info[len(full_info) - 1]
                        series = series.split(",")

                        if len(series) == 0:
                            raise Exception(
                                "A given series should contains a set of comma separated numeric values. At least one numeric value should be there in a series. Missing values should be indicated with ? symbol"
                            )

                        numeric_series = []

                        for val in series:
                            if val == "?":
                                numeric_series.append(replace_missing_vals_with)
                            else:
                                numeric_series.append(float(val))

                        if numeric_series.count(replace_missing_vals_with) == len(
                            numeric_series
                        ):
                            raise Exception(
                                "All series values are missing. A given series should contains a set of comma separated numeric values. At least one numeric value should be there in a series."
                            )

                        all_series.append(pd.Series(numeric_series).array)

                        for i in range(len(col_names)):
                            att_val = None
                            if col_types[i] == "numeric":
                                att_val = int(full_info[i])
                            elif col_types[i] == "string":
                                att_val = str(full_info[i])
                            elif col_types[i] == "date":
                                att_val = datetime.strptime(
                                    full_info[i], "%Y-%m-%d %H-%M-%S"
                                )
                            else:
                                raise Exception(
                                    "Invalid attribute type."
                                )  # Currently, the code supports only numeric, string and date types. Extend this as required.

                            if att_val is None:
                                raise Exception("Invalid attribute value.")
                            else:
                                all_data[col_names[i]].append(att_val)

                line_count = line_count + 1

        if line_count == 0:
            raise Exception("Empty file.")
        if len(col_names) == 0:
            raise Exception("Missing attribute section.")
        if not found_data_section:
            raise Exception("Missing series information under data section.")

        all_data[value_column_name] = all_series
        loaded_data = pd.DataFrame(all_data)

        return (
            loaded_data,
            frequency,
            forecast_horizon,
            contain_missing_values,
            contain_equal_length,
        )


# Example of usage
# loaded_data, frequency, forecast_horizon, contain_missing_values, contain_equal_length = convert_tsf_to_dataframe("TSForecasting/tsf_data/sample.tsf")

# print(loaded_data)
# print(frequency)
# print(forecast_horizon)
# print(contain_missing_values)
# print(contain_equal_length)

# %%
def convert_to_pandas_frequency(frequency_str):
    # Dictionary to map units to pandas frequency codes
    unit_map = {
        'second': 'S',
        'seconds': 'S',
        'minute': 'T',
        'minutes': 'T',
        'hour': 'H',
        'hours': 'H',
        'hourly': 'H',
        'day': 'D',
        'days': 'D',
        'daily': 'D',
        'week': 'W',
        'weeks': 'W',
        'weekly': 'W',
        'month': 'M',
        'months': 'M',
        'monthly': 'M',
        'year': 'A',
        'years': 'A',
        'yearly': 'A',
        'quarter': 'Q',
        'quarters': 'Q',
        'quarterly': 'Q'
    }
    
    # Split the input string to get the number and unit
    parts = frequency_str.split('_')
    if len(parts) == 1:
        number = 1
        unit = parts[0]
        #raise ValueError("Input format should be '<number>_<unit>'")
    elif len(parts) ==2:
        number, unit = parts
        # Dict"ionary to map each unit to its half-unit equivalent
        half_unit_map = {
            'A': ('Q', 2),  # Half of a year is 2 quarters
            'Q': ('M', 2),  # Half of a quarter is 2 months
            'M': ('D', 15),  # Approximate half of a month is 15 days
            'W': ('D', 3.5),  # Half of a week is 3.5 days
            'D': ('H', 12),  # Half of a day is 12 hours
            'H': ('T', 30),  # Half of an hour is 30 minutes
            'T': ('S', 30)  # Half of a minute is 30 seconds
        }
    
        if number == 'half':
            # Get the unit key from the unit map
            unit_key = unit_map[unit]
            
            # Get the half-unit equivalent from the half_unit_map
            if unit_key in half_unit_map:
                half_unit, half_number = half_unit_map[unit_key]
                pandas_frequency = f"{int(half_number)}{half_unit}"
                return pandas_frequency
            else:
                raise ValueError(f"Half unit mapping not available for unit '{unit}'")
        else:
            try:
                number = int(number)
            except ValueError:
                raise ValueError("The number part of the input should be an integer")
    else:
        raise ValueError("Input format should be '<number>_<unit>' Maybe update unit_map")
    

    
    if unit not in unit_map:
        raise ValueError(f"Unit '{unit}' is not recognized")
    
    # Convert to pandas frequency string
    pandas_frequency = f"{number}{unit_map[unit]}"
    return pandas_frequency

# %%
def generate_timestamps(start_timestamp, frequency, values):
    # Generate a range of timestamps
    timestamps = pd.date_range(start=start_timestamp, periods=len(values), freq=convert_to_pandas_frequency(frequency))
    
    # Create a DataFrame with the values and the generated timestamps
    df = pd.DataFrame({'Timestamp': timestamps, 'Value': values})
    
    return df

# %%
df_list = []
for file in files:
    name = file.split('/')[-1].split('.tsf')[0]
    loaded_data, frequency, forecast_horizon, contain_missing_values, contain_equal_length = convert_tsf_to_dataframe(file)
    for index, row in loaded_data.iterrows():
        serie_name = name + '_' + row['series_name']
        serie = generate_timestamps(row['start_timestamp'], frequency, row['series_value'])
        df_list.append({'name': serie_name, 'serie': serie})
        serie.to_csv("./files/" + serie_name + ".csv", index=False)
    os.remove(file)

# %%
df_list
# Out:
# [{'name': 'bitcoin_dataset_with_missing_values_difficulty',
#   'serie':       Timestamp             Value
#   0    2009-01-03               1.0
#   1    2009-01-04               NaN
#   2    2009-01-05               NaN
#   3    2009-01-06               NaN
#   4    2009-01-07               NaN
#   ...         ...               ...
#   4576 2021-07-15  14363025673660.0
#   4577 2021-07-16  14363025673660.0
#   4578 2021-07-17  14348541098817.0
#   4579 2021-07-18  13672594272814.0
#   4580 2021-07-19               NaN
#
#   [4581 rows x 2 columns]},
#  {'name': 'bitcoin_dataset_with_missing_values_sent_addresses',
#   'serie':       Timestamp     Value
#   0    2009-01-03       NaN
#   1    2009-01-04       NaN
#   2    2009-01-05       NaN
#   3    2009-01-06       NaN
#   4    2009-01-07       NaN
#   ...         ...       ...
#   4576 2021-07-15  386824.0
#   4577 2021-07-16  350835.0
#   4578 2021-07-17  269883.0
#   4579 2021-07-18  187721.0
#   4580 2021-07-19       NaN
#
#   [4581 rows x 2 columns]},
#  {'name': 'bitcoin_dataset_with_missing_values_send_usd',
#   'serie':       Timestamp          Value
#   0    2009-01-03            NaN
#   1    2009-01-04            NaN
#   2    2009-01-05            NaN
#   3    2009-01-06            NaN
#   4    2009-01-07            NaN
#   ...         ...            ...
#   4576 2021-07-15  16363800845.0
#   4577 2021-07-16  12231055118.0
#   4578 2021-07-17  15303994562.0
#   4579 2021-07-18   7945136415.0
#   4580 2021-07-19            NaN
#
#   [4581 rows x 2 columns]},
#  {'name': 'bitcoin_dataset_with_missing_values_market_cap',
#   'serie':       Timestamp           Value
#   0    2009-01-03             NaN
#   1    2009-01-04             NaN
#   2    2009-01-05             NaN
#   3    2009-01-06             NaN
#   4    2009-01-07             NaN
#   ...         ...             ...
#   4576 2021-07-15  602284376905.0
#   4577 2021-07-16  595575743867.0
#   4578 2021-07-17  591956104990.0
#   4579 2021-07-18  595880906407.0
#   4580 2021-07-19             NaN
#
#   [4581 rows x 2 columns]},
#  {'name': 'bitcoin_dataset_with_missing_values_confirmation_time',
#   'serie':       Timestamp  Value
#   0    2009-01-03    NaN
#   1    2009-01-04    NaN
#   2    2009-01-05    NaN
#   3    2009-01-06    NaN
#   4    2009-01-07    NaN
#   ...         ...    ...
#   4576 2021-07-15  11.25
#   4577 2021-07-16    9.6
#   4578 2021-07-17  10.07
#   4579 2021-07-18   10.0
#   4580 2021-07-19    NaN
#
#   [4581 rows x 2 columns]},
#  {'name': 'bitcoin_dataset_with_missing_values_transactions',
#   'serie':       Timestamp     Value
#   0    2009-01-03       NaN
#   1    2009-01-04       NaN
#   2    2009-01-05       NaN
#   3    2009-01-06       NaN
#   4    2009-01-07       NaN
#   ...         ...       ...
#   4576 2021-07-15  226106.0
#   4577 2021-07-16  223316.0
#   4578 2021-07-17  181904.0
#   4579 2021-07-18  160978.0
#   4580 2021-07-19       NaN
#
#   [4581 rows x 2 columns]},
#  {'name': 'bitcoin_dataset_with_missing_values_median_transaction_size',
#   'serie':       Timestamp  Value
#   0    2009-01-03    NaN
#   1    2009-01-04    NaN
#   2    2009-01-05    NaN
#   3    2009-01-06    NaN
#   4    2009-01-07    NaN
#   ...         ...    ...
#   4576 2021-07-15   0.77
#   4577 2021-07-16  0.574
#   4578 2021-07-17  0.415
#   4579 2021-07-18  0.325
#   4580 2021-07-19    NaN
#
#   [4581 rows x 2 columns]},
#  {'name': 'bitcoin_dataset_with_missing_values_mining_profitability',
#   'serie':       Timestamp  Value
#   0    2009-01-03    NaN
#   1    2009-01-04    NaN
#   2    2009-01-05    NaN
#   3    2009-01-06    NaN
#   4    2009-01-07    NaN
#   ...         ...    ...
#   4576 2021-07-15  0.248
#   4577 2021-07-16  0.297
#   4578 2021-07-17  0.262
#   4579 2021-07-18  0.298
#   4580 2021-07-19    NaN
#
#   [4581 rows x 2 columns]},
#  {'name': 'bitcoin_dataset_with_missing_values_fee_reward',
#   'serie':       Timestamp  Value
#   0    2009-01-03    NaN
#   1    2009-01-04    NaN
#   2    2009-01-05    NaN
#   3    2009-01-06    NaN
#   4    2009-01-07    NaN
#   ...         ...    ...
#   4576 2021-07-15  2.763
#   4577 2021-07-16  1.812
#   4578 2021-07-17  1.393
#   4579 2021-07-18  1.324
#   4580 2021-07-19    NaN
#
#   [4581 rows x 2 columns]},
#  {'name': 'bitcoin_dataset_with_missing_values_top_100_percent',
#   'serie':       Timestamp   Value
#   0    2009-01-03     NaN
#   1    2009-01-04     NaN
#   2    2009-01-05     NaN
#   3    2009-01-06     NaN
#   4    2009-01-07     NaN
#   ...         ...     ...
#   4576 2021-07-15  15.332
#   4577 2021-07-16  15.355
#   4578 2021-07-17  15.233
#   4579 2021-07-18   15.22
#   4580 2021-07-19  15.217
#
#   [4581 rows x 2 columns]},
#  {'name': 'bitcoin_dataset_with_missing_values_median_transaction_value',
#   'serie':       Timestamp    Value
#   0    2009-01-03      NaN
#   1    2009-01-04      NaN
#   2    2009-01-05      NaN
#   3    2009-01-06      NaN
#   4    2009-01-07      NaN
#   ...         ...      ...
#   4576 2021-07-15  794.361
#   4577 2021-07-16  715.468
#   4578 2021-07-17  629.852
#   4579 2021-07-18  644.551
#   4580 2021-07-19      NaN
#
#   [4581 rows x 2 columns]},
#  {'name': 'bitcoin_dataset_with_missing_values_av_transaction_value',
#   'serie':       Timestamp     Value
#   0    2009-01-03       NaN
#   1    2009-01-04       NaN
#   2    2009-01-05       NaN
#   3    2009-01-06       NaN
#   4    2009-01-07       NaN
#   ...         ...       ...
#   4576 2021-07-15  262533.0
#   4577 2021-07-16  259940.0
#   4578 2021-07-17  322240.0
#   4579 2021-07-18  231237.0
#   4580 2021-07-19       NaN
#
#   [4581 rows x 2 columns]},
#  {'name': 'bitcoin_dataset_with_missing_values_block_size',
#   'serie':       Timestamp     Value
#   0    2009-01-03     204.0
#   1    2009-01-04       NaN
#   2    2009-01-05       NaN
#   3    2009-01-06       NaN
#   4    2009-01-07       NaN
#   ...         ...       ...
#   4576 2021-07-15  739841.0
#   4577 2021-07-16  562742.0
#   4578 2021-07-17  475044.0
#   4579 2021-07-18  480527.0
#   4580 2021-07-19       NaN
#
#   [4581 rows x 2 columns]},
#  {'name': 'bitcoin_dataset_with_missing_values_hashrate',
#   'serie':       Timestamp                    Value
#   0    2009-01-03                      NaN
#   1    2009-01-04                      NaN
#   2    2009-01-05                      NaN
#   3    2009-01-06                      NaN
#   4    2009-01-07                      NaN
#   ...         ...                      ...
#   4576 2021-07-15  106487108039519993856.0
#   4577 2021-07-16  102205934890269999104.0
#   4578 2021-07-17  109244399681640005632.0
#   4579 2021-07-18   97182855611720007680.0
#   4580 2021-07-19                      NaN
#
#   [4581 rows x 2 columns]},
#  {'name': 'bitcoin_dataset_with_missing_values_active_addresses',
#   'serie':       Timestamp     Value
#   0    2009-01-03       NaN
#   1    2009-01-04       NaN
#   2    2009-01-05       NaN
#   3    2009-01-06       NaN
#   4    2009-01-07       NaN
#   ...         ...       ...
#   4576 2021-07-15  714198.0
#   4577 2021-07-16  661189.0
#   4578 2021-07-17  548038.0
#   4579 2021-07-18  535632.0
#   4580 2021-07-19  651492.0
#
#   [4581 rows x 2 columns]},
#  {'name': 'bitcoin_dataset_with_missing_values_google_trends',
#   'serie':       Timestamp   Value
#   0    2009-01-03     NaN
#   1    2009-01-04     NaN
#   2    2009-01-05     NaN
#   3    2009-01-06     NaN
#   4    2009-01-07     NaN
#   ...         ...     ...
#   4576 2021-07-15  92.666
#   4577 2021-07-16  90.511
#   4578 2021-07-17     NaN
#   4579 2021-07-18     NaN
#   4580 2021-07-19     NaN
#
#   [4581 rows x 2 columns]},
#  {'name': 'bitcoin_dataset_with_missing_values_tweets',
#   'serie':       Timestamp    Value
#   0    2009-01-03      NaN
#   1    2009-01-04      NaN
#   2    2009-01-05      NaN
#   3    2009-01-06      NaN
#   4    2009-01-07      NaN
#   ...         ...      ...
#   4576 2021-07-15  92346.0
#   4577 2021-07-16  86926.0
#   4578 2021-07-17  73357.0
#   4579 2021-07-18  75089.0
#   4580 2021-07-19  46377.0
#
#   [4581 rows x 2 columns]},
#  {'name': 'bitcoin_dataset_with_missing_values_price',
#   'serie':       Timestamp    Value
#   0    2009-01-03      NaN
#   1    2009-01-04      NaN
#   2    2009-01-05      NaN
#   3    2009-01-06      NaN
#   4    2009-01-07      NaN
#   ...         ...      ...
#   4576 2021-07-15  32109.0
#   4577 2021-07-16  31750.0
#   4578 2021-07-17  31556.0
#   4579 2021-07-18  31763.0
#   4580 2021-07-19  30593.0
#
#   [4581 rows x 2 columns]},
#  {'name': 'bitcoin_dataset_without_missing_values_difficulty',
#   'serie':       Timestamp         Value
#   0    2009-01-03  1.000000e+00
#   1    2009-01-04  1.000000e+00
#   2    2009-01-05  1.000000e+00
#   3    2009-01-06  1.000000e+00
#   4    2009-01-07  1.000000e+00
#   ...         ...           ...
#   4576 2021-07-15  1.436303e+13
#   4577 2021-07-16  1.436303e+13
#   4578 2021-07-17  1.434854e+13
#   4579 2021-07-18  1.367259e+13
#   4580 2021-07-19  1.367259e+13
#
#   [4581 rows x 2 columns]},
#  {'name': 'bitcoin_dataset_without_missing_values_sent_addresses',
#   'serie':       Timestamp     Value
#   0    2009-01-09       1.0
#   1    2009-01-10       1.0
#   2    2009-01-11       1.0
#   3    2009-01-12       7.0
#   4    2009-01-13      10.0
#   ...         ...       ...
#   4570 2021-07-15  386824.0
#   4571 2021-07-16  350835.0
#   4572 2021-07-17  269883.0
#   4573 2021-07-18  187721.0
#   4574 2021-07-19  187721.0
#
#   [4575 rows x 2 columns]},
#  {'name': 'bitcoin_dataset_without_missing_values_send_usd',
#   'serie':       Timestamp         Value
#   0    2010-07-17  1.193000e+03
#   1    2010-07-18  2.612000e+03
#   2    2010-07-19  4.047000e+03
#   3    2010-07-20  2.341000e+03
#   4    2010-07-21  2.122000e+03
#   ...         ...           ...
#   4016 2021-07-15  1.636380e+10
#   4017 2021-07-16  1.223106e+10
#   4018 2021-07-17  1.530399e+10
#   4019 2021-07-18  7.945136e+09
#   4020 2021-07-19  7.945136e+09
#
#   [4021 rows x 2 columns]},
#  {'name': 'bitcoin_dataset_without_missing_values_market_cap',
#   'serie':       Timestamp         Value
#   0    2010-07-17  1.698390e+05
#   1    2010-07-18  2.497610e+05
#   2    2010-07-19  2.959810e+05
#   3    2010-07-20  2.705460e+05
#   4    2010-07-21  2.659000e+05
#   ...         ...           ...
#   4016 2021-07-15  6.022844e+11
#   4017 2021-07-16  5.955757e+11
#   4018 2021-07-17  5.919561e+11
#   4019 2021-07-18  5.958809e+11
#   4020 2021-07-19  5.958809e+11
#
#   [4021 rows x 2 columns]},
#  {'name': 'bitcoin_dataset_without_missing_values_confirmation_time',
#   'serie':       Timestamp    Value
#   0    2009-01-09  102.857
#   1    2009-01-10   23.607
#   2    2009-01-11   15.484
#   3    2009-01-12   15.319
#   4    2009-01-13   11.707
#   ...         ...      ...
#   4570 2021-07-15   11.250
#   4571 2021-07-16    9.600
#   4572 2021-07-17   10.070
#   4573 2021-07-18   10.000
#   4574 2021-07-19   10.000
#
#   [4575 rows x 2 columns]},
#  {'name': 'bitcoin_dataset_without_missing_values_transactions',
#   'serie':       Timestamp     Value
#   0    2009-01-12       7.0
#   1    2009-01-13       7.0
#   2    2009-01-14       1.0
#   3    2009-01-15       8.0
#   4    2009-01-16       2.0
#   ...         ...       ...
#   4567 2021-07-15  226106.0
#   4568 2021-07-16  223316.0
#   4569 2021-07-17  181904.0
#   4570 2021-07-18  160978.0
#   4571 2021-07-19  160978.0
#
#   [4572 rows x 2 columns]},
#  {'name': 'bitcoin_dataset_without_missing_values_median_transaction_size',
#   'serie':       Timestamp   Value
#   0    2011-04-14  0.0097
#   1    2011-04-15  0.0097
#   2    2011-04-16  0.0097
#   3    2011-04-17  0.0097
#   4    2011-04-18  0.0097
#   ...         ...     ...
#   3745 2021-07-15  0.7700
#   3746 2021-07-16  0.5740
#   3747 2021-07-17  0.4150
#   3748 2021-07-18  0.3250
#   3749 2021-07-19  0.3250
#
#   [3750 rows x 2 columns]},
#  {'name': 'bitcoin_dataset_without_missing_values_mining_profitability',
#   'serie':       Timestamp       Value
#   0    2010-07-17  154298.000
#   1    2010-07-18  401834.000
#   2    2010-07-19  481473.000
#   3    2010-07-20  431831.000
#   4    2010-07-21  460783.000
#   ...         ...         ...
#   4016 2021-07-15       0.248
#   4017 2021-07-16       0.297
#   4018 2021-07-17       0.262
#   4019 2021-07-18       0.298
#   4020 2021-07-19       0.298
#
#   [4021 rows x 2 columns]},
#  {'name': 'bitcoin_dataset_without_missing_values_fee_reward',
#   'serie':       Timestamp    Value
#   0    2010-07-17  0.00100
#   1    2010-07-18  0.01630
#   2    2010-07-19  0.00154
#   3    2010-07-20  0.00154
#   4    2010-07-21  0.00154
#   ...         ...      ...
#   4016 2021-07-15  2.76300
#   4017 2021-07-16  1.81200
#   4018 2021-07-17  1.39300
#   4019 2021-07-18  1.32400
#   4020 2021-07-19  1.32400
#
#   [4021 rows x 2 columns]},
#  {'name': 'bitcoin_dataset_without_missing_values_top_100_percent',
#   'serie':       Timestamp    Value
#   0    2009-01-09  100.000
#   1    2009-01-10  100.000
#   2    2009-01-11   59.524
#   3    2009-01-12   38.168
#   4    2009-01-13   25.974
#   ...         ...      ...
#   4570 2021-07-15   15.332
#   4571 2021-07-16   15.355
#   4572 2021-07-17   15.233
#   4573 2021-07-18   15.220
#   4574 2021-07-19   15.217
#
#   [4575 rows x 2 columns]},
#  {'name': 'bitcoin_dataset_without_missing_values_median_transaction_value',
#   'serie':       Timestamp    Value
#   0    2010-07-17    0.248
#   1    2010-07-18    0.363
#   2    2010-07-19    0.429
#   3    2010-07-20    5.105
#   4    2010-07-21    3.837
#   ...         ...      ...
#   4016 2021-07-15  794.361
#   4017 2021-07-16  715.468
#   4018 2021-07-17  629.852
#   4019 2021-07-18  644.551
#   4020 2021-07-19  644.551
#
#   [4021 rows x 2 columns]},
#  {'name': 'bitcoin_dataset_without_missing_values_av_transaction_value',
#   'serie':       Timestamp       Value
#   0    2010-07-17       2.924
#   1    2010-07-18       6.237
#   2    2010-07-19       7.666
#   3    2010-07-20       3.940
#   4    2010-07-21       4.583
#   ...         ...         ...
#   4016 2021-07-15  262533.000
#   4017 2021-07-16  259940.000
#   4018 2021-07-17  322240.000
#   4019 2021-07-18  231237.000
#   4020 2021-07-19  231237.000
#
#   [4021 rows x 2 columns]},
#  {'name': 'bitcoin_dataset_without_missing_values_block_size',
#   'serie':       Timestamp     Value
#   0    2009-01-03     204.0
#   1    2009-01-04     204.0
#   2    2009-01-05     204.0
#   3    2009-01-06     204.0
#   4    2009-01-07     204.0
#   ...         ...       ...
#   4576 2021-07-15  739841.0
#   4577 2021-07-16  562742.0
#   4578 2021-07-17  475044.0
#   4579 2021-07-18  480527.0
#   4580 2021-07-19  480527.0
#
#   [4581 rows x 2 columns]},
#  {'name': 'bitcoin_dataset_without_missing_values_hashrate',
#   'serie':       Timestamp         Value
#   0    2009-01-09  1.257632e+07
#   1    2009-01-10  9.378233e+06
#   2    2009-01-11  4.857511e+06
#   3    2009-01-12  4.567766e+06
#   4    2009-01-13  5.654593e+06
#   ...         ...           ...
#   4570 2021-07-15  1.064871e+20
#   4571 2021-07-16  1.022059e+20
#   4572 2021-07-17  1.092444e+20
#   4573 2021-07-18  9.718286e+19
#   4574 2021-07-19  9.718286e+19
#
#   [4575 rows x 2 columns]},
#  {'name': 'bitcoin_dataset_without_missing_values_active_addresses',
#   'serie':       Timestamp     Value
#   0    2009-01-09      14.0
#   1    2009-01-10      61.0
#   2    2009-01-11      93.0
#   3    2009-01-12     102.0
#   4    2009-01-13     123.0
#   ...         ...       ...
#   4570 2021-07-15  714198.0
#   4571 2021-07-16  661189.0
#   4572 2021-07-17  548038.0
#   4573 2021-07-18  535632.0
#   4574 2021-07-19  651492.0
#
#   [4575 rows x 2 columns]},
#  {'name': 'bitcoin_dataset_without_missing_values_google_trends',
#   'serie':       Timestamp      Value
#   0    2010-01-20   0.000534
#   1    2010-01-21   0.000534
#   2    2010-01-22   0.000534
#   3    2010-01-23   0.000534
#   4    2010-01-24   0.000534
#   ...         ...        ...
#   4194 2021-07-15  92.666000
#   4195 2021-07-16  90.511000
#   4196 2021-07-17  90.511000
#   4197 2021-07-18  90.511000
#   4198 2021-07-19  90.511000
#
#   [4199 rows x 2 columns]},
#  {'name': 'bitcoin_dataset_without_missing_values_tweets',
#   'serie':       Timestamp    Value
#   0    2014-04-09   8193.0
#   1    2014-04-10  15039.0
#   2    2014-04-11  14907.0
#   3    2014-04-12   7582.0
#   4    2014-04-13  10674.0
#   ...         ...      ...
#   2654 2021-07-15  92346.0
#   2655 2021-07-16  86926.0
#   2656 2021-07-17  73357.0
#   2657 2021-07-18  75089.0
#   2658 2021-07-19  46377.0
#
#   [2659 rows x 2 columns]},
#  {'name': 'bitcoin_dataset_without_missing_values_price',
#   'serie':       Timestamp       Value
#   0    2010-07-17      0.0495
#   1    2010-07-18      0.0726
#   2    2010-07-19      0.0859
#   3    2010-07-20      0.0783
#   4    2010-07-21      0.0767
#   ...         ...         ...
#   4016 2021-07-15  32109.0000
#   4017 2021-07-16  31750.0000
#   4018 2021-07-17  31556.0000
#   4019 2021-07-18  31763.0000
#   4020 2021-07-19  30593.0000
#
#   [4021 rows x 2 columns]},
#  {'name': 'fred_md_dataset_T1',
#   'serie':      Timestamp      Value
#   0   1959-01-31   2437.296
#   1   1959-02-28   2446.902
#   2   1959-03-31   2462.689
#   3   1959-04-30   2478.744
#   4   1959-05-31   2493.228
#   ..         ...        ...
#   723 2019-04-30  16935.502
#   724 2019-05-31  16979.701
#   725 2019-06-30  17032.129
#   726 2019-07-31  17013.115
#   727 2019-08-31  17074.432
#
#   [728 rows x 2 columns]},
#  {'name': 'fred_md_dataset_T2',
#   'serie':      Timestamp    Value
#   0   1959-01-31   2288.8
#   1   1959-02-28   2297.0
#   2   1959-03-31   2314.0
#   3   1959-04-30   2330.3
#   4   1959-05-31   2345.8
#   ..         ...      ...
#   723 2019-04-30  14062.4
#   724 2019-05-31  14096.2
#   725 2019-06-30  14138.7
#   726 2019-07-31  14116.8
#   727 2019-08-31  14170.1
#
#   [728 rows x 2 columns]},
#  {'name': 'fred_md_dataset_T3',
#   'serie':      Timestamp    Value
#   0   1959-01-31   17.302
#   1   1959-02-28   17.482
#   2   1959-03-31   17.647
#   3   1959-04-30   17.584
#   4   1959-05-31   17.796
#   ..         ...      ...
#   723 2019-04-30  120.025
#   724 2019-05-31  120.433
#   725 2019-06-30  120.683
#   726 2019-07-31  120.997
#   727 2019-08-31  121.123
#
#   [728 rows x 2 columns]},
#  {'name': 'fred_md_dataset_T4',
#   'serie':      Timestamp      Value
#   0   1959-01-31   18235.77
#   1   1959-02-28   18369.56
#   2   1959-03-31   18523.06
#   3   1959-04-30   18534.47
#   4   1959-05-31   18679.66
#   ..         ...        ...
#   723 2019-04-30  515545.00
#   724 2019-05-31  518131.00
#   725 2019-06-30  520055.00
#   726 2019-07-31  524165.00
#   727 2019-08-31  526057.00
#
#   [728 rows x 2 columns]},
#  {'name': 'fred_md_dataset_T5',
#   'serie':      Timestamp     Value
#   0   1959-01-31   22.6250
#   1   1959-02-28   23.0681
#   2   1959-03-31   23.4004
#   3   1959-04-30   23.8989
#   4   1959-05-31   24.2589
#   ..         ...       ...
#   723 2019-04-30  108.9865
#   724 2019-05-31  109.2429
#   725 2019-06-30  109.3599
#   726 2019-07-31  109.2143
#   727 2019-08-31  109.9206
#
#   [728 rows x 2 columns]},
#  {'name': 'fred_md_dataset_T6',
#   'serie':      Timestamp     Value
#   0   1959-01-31   23.4581
#   1   1959-02-28   23.7747
#   2   1959-03-31   23.9186
#   3   1959-04-30   24.2641
#   4   1959-05-31   24.4655
#   ..         ...       ...
#   723 2019-04-30  103.8235
#   724 2019-05-31  104.3521
#   725 2019-06-30  104.7702
#   726 2019-07-31  104.6044
#   727 2019-08-31  105.1011
#
#   [728 rows x 2 columns]},
#  {'name': 'fred_md_dataset_T7',
#   'serie':      Timestamp     Value
#   0   1959-01-31   22.1904
#   1   1959-02-28   22.3827
#   2   1959-03-31   22.4925
#   3   1959-04-30   22.8221
#   4   1959-05-31   23.0418
#   ..         ...       ...
#   723 2019-04-30  102.5216
#   724 2019-05-31  103.0376
#   725 2019-06-30  103.6698
#   726 2019-07-31  103.5382
#   727 2019-08-31  103.9269
#
#   [728 rows x 2 columns]},
#  {'name': 'fred_md_dataset_T8',
#   'serie':      Timestamp     Value
#   0   1959-01-31   32.4078
#   1   1959-02-28   32.6455
#   2   1959-03-31   32.6455
#   3   1959-04-30   33.1606
#   4   1959-05-31   33.3190
#   ..         ...       ...
#   723 2019-04-30  104.4575
#   724 2019-05-31  105.0794
#   725 2019-06-30  105.6588
#   726 2019-07-31  105.7892
#   727 2019-08-31  105.9832
#
#   [728 rows x 2 columns]},
#  {'name': 'fred_md_dataset_T9',
#   'serie':      Timestamp     Value
#   0   1959-01-31   21.9882
#   1   1959-02-28   22.1036
#   2   1959-03-31   22.5365
#   3   1959-04-30   22.6807
#   4   1959-05-31   23.1424
#   ..         ...       ...
#   723 2019-04-30  118.1618
#   724 2019-05-31  120.4801
#   725 2019-06-30  122.4274
#   726 2019-07-31  122.5438
#   727 2019-08-31  122.3292
#
#   [728 rows x 2 columns]},
#  {'name': 'fred_md_dataset_T10',
#   'serie':      Timestamp     Value
#   0   1959-01-31   37.7280
#   1   1959-02-28   38.0886
#   2   1959-03-31   37.9083
#   3   1959-04-30   38.5393
#   4   1959-05-31   38.5393
#   ..         ...       ...
#   723 2019-04-30  100.9801
#   724 2019-05-31  101.1794
#   725 2019-06-30  101.4176
#   726 2019-07-31  101.5514
#   727 2019-08-31  101.8472
#
#   [728 rows x 2 columns]},
#  {'name': 'fred_md_dataset_T11',
#   'serie':      Timestamp     Value
#   0   1959-01-31    7.9955
#   1   1959-02-28    8.1025
#   2   1959-03-31    8.1900
#   3   1959-04-30    8.4040
#   4   1959-05-31    8.6764
#   ..         ...       ...
#   723 2019-04-30  100.8357
#   724 2019-05-31  101.2933
#   725 2019-06-30  101.9418
#   726 2019-07-31  101.3134
#   727 2019-08-31  102.3467
#
#   [728 rows x 2 columns]},
#  {'name': 'fred_md_dataset_T12',
#   'serie':      Timestamp     Value
#   0   1959-01-31   21.2146
#   1   1959-02-28   21.8864
#   2   1959-03-31   22.4549
#   3   1959-04-30   23.0751
#   4   1959-05-31   23.6694
#   ..         ...       ...
#   723 2019-04-30  114.7893
#   724 2019-05-31  114.6911
#   725 2019-06-30  114.4141
#   726 2019-07-31  114.2963
#   727 2019-08-31  115.2718
#
#   [728 rows x 2 columns]},
#  {'name': 'fred_md_dataset_T13',
#   'serie':      Timestamp     Value
#   0   1959-01-31   12.6047
#   1   1959-02-28   13.1853
#   2   1959-03-31   13.7048
#   3   1959-04-30   14.1173
#   4   1959-05-31   14.6062
#   ..         ...       ...
#   723 2019-04-30  107.4001
#   724 2019-05-31  107.2815
#   725 2019-06-30  107.7241
#   726 2019-07-31  107.2339
#   727 2019-08-31  107.9056
#
#   [728 rows x 2 columns]},
#  {'name': 'fred_md_dataset_T14',
#   'serie':      Timestamp     Value
#   0   1959-01-31   30.5372
#   1   1959-02-28   31.0719
#   2   1959-03-31   31.5387
#   3   1959-04-30   32.5154
#   4   1959-05-31   32.8075
#   ..         ...       ...
#   723 2019-04-30  103.0359
#   724 2019-05-31  102.6894
#   725 2019-06-30  102.0140
#   726 2019-07-31  101.8598
#   727 2019-08-31  102.3075
#
#   [728 rows x 2 columns]},
#  {'name': 'fred_md_dataset_T15',
#   'serie':      Timestamp     Value
#   0   1959-01-31   21.1492
#   1   1959-02-28   21.5379
#   2   1959-03-31   21.8749
#   3   1959-04-30   22.3414
#   4   1959-05-31   22.6524
#   ..         ...       ...
#   723 2019-04-30  104.3399
#   724 2019-05-31  104.4620
#   725 2019-06-30  105.0892
#   726 2019-07-31  104.6780
#   727 2019-08-31  105.2156
#
#   [728 rows x 2 columns]},
#  {'name': 'fred_md_dataset_T16',
#   'serie':      Timestamp     Value
#   0   1959-01-31   20.2590
#   1   1959-02-28   20.2038
#   2   1959-03-31   20.3417
#   3   1959-04-30   20.4243
#   4   1959-05-31   20.7275
#   ..         ...       ...
#   723 2019-04-30  105.1347
#   724 2019-05-31  109.9737
#   725 2019-06-30  103.0693
#   726 2019-07-31  107.8113
#   727 2019-08-31  108.4259
#
#   [728 rows x 2 columns]},
#  {'name': 'fred_md_dataset_T17',
#   'serie':      Timestamp     Value
#   0   1959-01-31   38.3482
#   1   1959-02-28   37.8258
#   2   1959-03-31   38.7835
#   3   1959-04-30   38.6093
#   4   1959-05-31   37.8694
#   ..         ...       ...
#   723 2019-04-30  110.0340
#   724 2019-05-31  110.7237
#   725 2019-06-30  109.4894
#   726 2019-07-31  110.3804
#   727 2019-08-31  110.1664
#
#   [728 rows x 2 columns]},
#  {'name': 'fred_md_dataset_T18',
#   'serie':      Timestamp    Value
#   0   1959-01-31  80.1973
#   1   1959-02-28  81.4428
#   2   1959-03-31  82.4769
#   3   1959-04-30  83.9922
#   4   1959-05-31  84.9159
#   ..         ...      ...
#   723 2019-04-30  75.4225
#   724 2019-05-31  75.4230
#   725 2019-06-30  75.7861
#   726 2019-07-31  75.4002
#   727 2019-08-31  75.6976
#
#   [728 rows x 2 columns]},
#  {'name': 'fred_md_dataset_T19',
#   'serie':      Timestamp     Value
#   0   1959-01-31   67936.0
#   1   1959-02-28   67649.0
#   2   1959-03-31   68068.0
#   3   1959-04-30   68339.0
#   4   1959-05-31   68178.0
#   ..         ...       ...
#   723 2019-04-30  162470.0
#   724 2019-05-31  162646.0
#   725 2019-06-30  162981.0
#   726 2019-07-31  163351.0
#   727 2019-08-31  163922.0
#
#   [728 rows x 2 columns]},
#  {'name': 'fred_md_dataset_T20',
#   'serie':      Timestamp     Value
#   0   1959-01-31   63868.0
#   1   1959-02-28   63684.0
#   2   1959-03-31   64267.0
#   3   1959-04-30   64768.0
#   4   1959-05-31   64699.0
#   ..         ...       ...
#   723 2019-04-30  156645.0
#   724 2019-05-31  156758.0
#   725 2019-06-30  157005.0
#   726 2019-07-31  157288.0
#   727 2019-08-31  157878.0
#
#   [728 rows x 2 columns]},
#  {'name': 'fred_md_dataset_T21',
#   'serie':      Timestamp  Value
#   0   1959-01-31    6.0
#   1   1959-02-28    5.9
#   2   1959-03-31    5.6
#   3   1959-04-30    5.2
#   4   1959-05-31    5.1
#   ..         ...    ...
#   723 2019-04-30    3.6
#   724 2019-05-31    3.6
#   725 2019-06-30    3.7
#   726 2019-07-31    3.7
#   727 2019-08-31    3.7
#
#   [728 rows x 2 columns]},
#  {'name': 'fred_md_dataset_T22',
#   'serie':      Timestamp  Value
#   0   1959-01-31   16.3
#   1   1959-02-28   15.5
#   2   1959-03-31   15.3
#   3   1959-04-30   14.9
#   4   1959-05-31   14.7
#   ..         ...    ...
#   723 2019-04-30   22.9
#   724 2019-05-31   24.1
#   725 2019-06-30   22.2
#   726 2019-07-31   19.6
#   727 2019-08-31   22.1
#
#   [728 rows x 2 columns]},
#  {'name': 'fred_md_dataset_T23',
#   'serie':      Timestamp   Value
#   0   1959-01-31  1574.0
#   1   1959-02-28  1554.0
#   2   1959-03-31  1459.0
#   3   1959-04-30  1494.0
#   4   1959-05-31  1479.0
#   ..         ...     ...
#   723 2019-04-30  1904.0
#   724 2019-05-31  2147.0
#   725 2019-06-30  1961.0
#   726 2019-07-31  2201.0
#   727 2019-08-31  2207.0
#
#   [728 rows x 2 columns]},
#  {'name': 'fred_md_dataset_T24',
#   'serie':      Timestamp   Value
#   0   1959-01-31  1169.0
#   1   1959-02-28  1164.0
#   2   1959-03-31  1093.0
#   3   1959-04-30   934.0
#   4   1959-05-31  1005.0
#   ..         ...     ...
#   723 2019-04-30  1842.0
#   724 2019-05-31  1559.0
#   725 2019-06-30  1830.0
#   726 2019-07-31  1797.0
#   727 2019-08-31  1757.0
#
#   [728 rows x 2 columns]},
#  {'name': 'fred_md_dataset_T25',
#   'serie':      Timestamp   Value
#   0   1959-01-31  1396.0
#   1   1959-02-28  1277.0
#   2   1959-03-31  1210.0
#   3   1959-04-30  1039.0
#   4   1959-05-31   965.0
#   ..         ...     ...
#   723 2019-04-30  2084.0
#   724 2019-05-31  2097.0
#   725 2019-06-30  2182.0
#   726 2019-07-31  2071.0
#   727 2019-08-31  2078.0
#
#   [728 rows x 2 columns]},
#  {'name': 'fred_md_dataset_T26',
#   'serie':      Timestamp  Value
#   0   1959-01-31  594.0
#   1   1959-02-28  545.0
#   2   1959-03-31  530.0
#   3   1959-04-30  408.0
#   4   1959-05-31  390.0
#   ..         ...    ...
#   723 2019-04-30  854.0
#   724 2019-05-31  799.0
#   725 2019-06-30  769.0
#   726 2019-07-31  905.0
#   727 2019-08-31  835.0
#
#   [728 rows x 2 columns]},
#  {'name': 'fred_md_dataset_T27',
#   'serie':      Timestamp   Value
#   0   1959-01-31   802.0
#   1   1959-02-28   732.0
#   2   1959-03-31   680.0
#   3   1959-04-30   631.0
#   4   1959-05-31   575.0
#   ..         ...     ...
#   723 2019-04-30  1230.0
#   724 2019-05-31  1298.0
#   725 2019-06-30  1414.0
#   726 2019-07-31  1166.0
#   727 2019-08-31  1243.0
#
#   [728 rows x 2 columns]},
#  {'name': 'fred_md_dataset_T28',
#   'serie':      Timestamp     Value
#   0   1959-01-31  291078.0
#   1   1959-02-28  282958.0
#   2   1959-03-31  260346.0
#   3   1959-04-30  246413.0
#   4   1959-05-31  246952.0
#   ..         ...       ...
#   723 2019-04-30  212500.0
#   724 2019-05-31  217500.0
#   725 2019-06-30  221800.0
#   726 2019-07-31  212000.0
#   727 2019-08-31  215600.0
#
#   [728 rows x 2 columns]},
#  {'name': 'fred_md_dataset_T29',
#   'serie':      Timestamp     Value
#   0   1959-01-31   52478.0
#   1   1959-02-28   52688.0
#   2   1959-03-31   53014.0
#   3   1959-04-30   53321.0
#   4   1959-05-31   53550.0
#   ..         ...       ...
#   723 2019-04-30  151012.0
#   724 2019-05-31  151074.0
#   725 2019-06-30  151252.0
#   726 2019-07-31  151411.0
#   727 2019-08-31  151541.0
#
#   [728 rows x 2 columns]},
#  {'name': 'fred_md_dataset_T30',
#   'serie':      Timestamp    Value
#   0   1959-01-31  18796.0
#   1   1959-02-28  18890.0
#   2   1959-03-31  19069.0
#   3   1959-04-30  19269.0
#   4   1959-05-31  19378.0
#   ..         ...      ...
#   723 2019-04-30  21072.0
#   724 2019-05-31  21077.0
#   725 2019-06-30  21104.0
#   726 2019-07-31  21102.0
#   727 2019-08-31  21114.0
#
#   [728 rows x 2 columns]},
#  {'name': 'fred_md_dataset_T31',
#   'serie':      Timestamp  Value
#   0   1959-01-31  713.0
#   1   1959-02-28  704.2
#   2   1959-03-31  704.1
#   3   1959-04-30  705.2
#   4   1959-05-31  710.0
#   ..         ...    ...
#   723 2019-04-30  710.3
#   724 2019-05-31  711.0
#   725 2019-06-30  708.8
#   726 2019-07-31  704.2
#   727 2019-08-31  698.6
#
#   [728 rows x 2 columns]},
#  {'name': 'fred_md_dataset_T32',
#   'serie':      Timestamp   Value
#   0   1959-01-31  2993.0
#   1   1959-02-28  2980.0
#   2   1959-03-31  3013.0
#   3   1959-04-30  3085.0
#   4   1959-05-31  3087.0
#   ..         ...     ...
#   723 2019-04-30  7482.0
#   724 2019-05-31  7483.0
#   725 2019-06-30  7502.0
#   726 2019-07-31  7500.0
#   727 2019-08-31  7514.0
#
#   [728 rows x 2 columns]},
#  {'name': 'fred_md_dataset_T33',
#   'serie':      Timestamp    Value
#   0   1959-01-31  14998.0
#   1   1959-02-28  15115.0
#   2   1959-03-31  15259.0
#   3   1959-04-30  15385.0
#   4   1959-05-31  15487.0
#   ..         ...      ...
#   723 2019-04-30  12834.0
#   724 2019-05-31  12836.0
#   725 2019-06-30  12846.0
#   726 2019-07-31  12850.0
#   727 2019-08-31  12853.0
#
#   [728 rows x 2 columns]},
#  {'name': 'fred_md_dataset_T34',
#   'serie':      Timestamp   Value
#   0   1959-01-31  8740.0
#   1   1959-02-28  8839.0
#   2   1959-03-31  8965.0
#   3   1959-04-30  9077.0
#   4   1959-05-31  9160.0
#   ..         ...     ...
#   723 2019-04-30  8055.0
#   724 2019-05-31  8058.0
#   725 2019-06-30  8067.0
#   726 2019-07-31  8069.0
#   727 2019-08-31  8069.0
#
#   [728 rows x 2 columns]},
#  {'name': 'fred_md_dataset_T35',
#   'serie':      Timestamp   Value
#   0   1959-01-31  6258.0
#   1   1959-02-28  6276.0
#   2   1959-03-31  6294.0
#   3   1959-04-30  6308.0
#   4   1959-05-31  6327.0
#   ..         ...     ...
#   723 2019-04-30  4779.0
#   724 2019-05-31  4778.0
#   725 2019-06-30  4779.0
#   726 2019-07-31  4781.0
#   727 2019-08-31  4784.0
#
#   [728 rows x 2 columns]},
#  {'name': 'fred_md_dataset_T36',
#   'serie':      Timestamp     Value
#   0   1959-01-31   33682.0
#   1   1959-02-28   33798.0
#   2   1959-03-31   33945.0
#   3   1959-04-30   34052.0
#   4   1959-05-31   34172.0
#   ..         ...       ...
#   723 2019-04-30  129940.0
#   724 2019-05-31  129997.0
#   725 2019-06-30  130148.0
#   726 2019-07-31  130309.0
#   727 2019-08-31  130427.0
#
#   [728 rows x 2 columns]},
#  {'name': 'fred_md_dataset_T37',
#   'serie':      Timestamp    Value
#   0   1959-01-31  10774.0
#   1   1959-02-28  10816.0
#   2   1959-03-31  10873.0
#   3   1959-04-30  10905.0
#   4   1959-05-31  10949.0
#   ..         ...      ...
#   723 2019-04-30  27809.0
#   724 2019-05-31  27807.0
#   725 2019-06-30  27815.0
#   726 2019-07-31  27817.0
#   727 2019-08-31  27806.0
#
#   [728 rows x 2 columns]},
#  {'name': 'fred_md_dataset_T38',
#   'serie':      Timestamp   Value
#   0   1959-01-31  2568.7
#   1   1959-02-28  2575.4
#   2   1959-03-31  2584.4
#   3   1959-04-30  2596.9
#   4   1959-05-31  2607.4
#   ..         ...     ...
#   723 2019-04-30  5929.8
#   724 2019-05-31  5935.2
#   725 2019-06-30  5934.1
#   726 2019-07-31  5941.4
#   727 2019-08-31  5944.3
#
#   [728 rows x 2 columns]},
#  {'name': 'fred_md_dataset_T39',
#   'serie':      Timestamp    Value
#   0   1959-01-31   5350.3
#   1   1959-02-28   5381.3
#   2   1959-03-31   5431.6
#   3   1959-04-30   5395.4
#   4   1959-05-31   5456.3
#   ..         ...      ...
#   723 2019-04-30  15787.0
#   724 2019-05-31  15774.8
#   725 2019-06-30  15762.8
#   726 2019-07-31  15757.7
#   727 2019-08-31  15746.6
#
#   [728 rows x 2 columns]},
#  {'name': 'fred_md_dataset_T40',
#   'serie':      Timestamp   Value
#   0   1959-01-31  2418.0
#   1   1959-02-28  2420.0
#   2   1959-03-31  2430.0
#   3   1959-04-30  2439.0
#   4   1959-05-31  2447.0
#   ..         ...     ...
#   723 2019-04-30  8651.0
#   724 2019-05-31  8656.0
#   725 2019-06-30  8659.0
#   726 2019-07-31  8679.0
#   727 2019-08-31  8694.0
#
#   [728 rows x 2 columns]},
#  {'name': 'fred_md_dataset_T41',
#   'serie':      Timestamp    Value
#   0   1959-01-31   8105.0
#   1   1959-02-28   8116.0
#   2   1959-03-31   8132.0
#   3   1959-04-30   8142.0
#   4   1959-05-31   8153.0
#   ..         ...      ...
#   723 2019-04-30  22531.0
#   724 2019-05-31  22512.0
#   725 2019-06-30  22529.0
#   726 2019-07-31  22557.0
#   727 2019-08-31  22591.0
#
#   [728 rows x 2 columns]},
#  {'name': 'fred_md_dataset_T42',
#   'serie':      Timestamp  Value
#   0   1959-01-31   39.8
#   1   1959-02-28   39.7
#   2   1959-03-31   40.0
#   3   1959-04-30   40.2
#   4   1959-05-31   40.3
#   ..         ...    ...
#   723 2019-04-30   41.1
#   724 2019-05-31   41.1
#   725 2019-06-30   41.2
#   726 2019-07-31   41.0
#   727 2019-08-31   41.1
#
#   [728 rows x 2 columns]},
#  {'name': 'fred_md_dataset_T43',
#   'serie':      Timestamp  Value
#   0   1959-01-31    2.5
#   1   1959-02-28    2.6
#   2   1959-03-31    2.8
#   3   1959-04-30    2.9
#   4   1959-05-31    2.9
#   ..         ...    ...
#   723 2019-04-30    4.3
#   724 2019-05-31    4.2
#   725 2019-06-30    4.2
#   726 2019-07-31    4.2
#   727 2019-08-31    4.2
#
#   [728 rows x 2 columns]},
#  {'name': 'fred_md_dataset_T44',
#   'serie':      Timestamp  Value
#   0   1959-01-31   40.2
#   1   1959-02-28   40.3
#   2   1959-03-31   40.4
#   3   1959-04-30   40.5
#   4   1959-05-31   40.7
#   ..         ...    ...
#   723 2019-04-30   41.7
#   724 2019-05-31   41.6
#   725 2019-06-30   41.7
#   726 2019-07-31   41.5
#   727 2019-08-31   41.6
#
#   [728 rows x 2 columns]},
#  {'name': 'fred_md_dataset_T45',
#   'serie':      Timestamp   Value
#   0   1959-01-31  1657.0
#   1   1959-02-28  1667.0
#   2   1959-03-31  1620.0
#   3   1959-04-30  1590.0
#   4   1959-05-31  1498.0
#   ..         ...     ...
#   723 2019-04-30  1270.0
#   724 2019-05-31  1264.0
#   725 2019-06-30  1233.0
#   726 2019-07-31  1215.0
#   727 2019-08-31  1364.0
#
#   [728 rows x 2 columns]},
#  {'name': 'fred_md_dataset_T46',
#   'serie':      Timestamp  Value
#   0   1959-01-31  350.0
#   1   1959-02-28  346.0
#   2   1959-03-31  330.0
#   3   1959-04-30  275.0
#   4   1959-05-31  260.0
#   ..         ...    ...
#   723 2019-04-30  132.0
#   724 2019-05-31   86.0
#   725 2019-06-30  111.0
#   726 2019-07-31   95.0
#   727 2019-08-31  124.0
#
#   [728 rows x 2 columns]},
#  {'name': 'fred_md_dataset_T47',
#   'serie':      Timestamp  Value
#   0   1959-01-31  452.0
#   1   1959-02-28  469.0
#   2   1959-03-31  413.0
#   3   1959-04-30  391.0
#   4   1959-05-31  355.0
#   ..         ...    ...
#   723 2019-04-30  162.0
#   724 2019-05-31  158.0
#   725 2019-06-30  182.0
#   726 2019-07-31  182.0
#   727 2019-08-31  210.0
#
#   [728 rows x 2 columns]},
#  {'name': 'fred_md_dataset_T48',
#   'serie':      Timestamp  Value
#   0   1959-01-31  505.0
#   1   1959-02-28  508.0
#   2   1959-03-31  503.0
#   3   1959-04-30  536.0
#   4   1959-05-31  487.0
#   ..         ...    ...
#   723 2019-04-30  649.0
#   724 2019-05-31  705.0
#   725 2019-06-30  632.0
#   726 2019-07-31  619.0
#   727 2019-08-31  711.0
#
#   [728 rows x 2 columns]},
#  {'name': 'fred_md_dataset_T49',
#   'serie':      Timestamp  Value
#   0   1959-01-31  350.0
#   1   1959-02-28  344.0
#   2   1959-03-31  374.0
#   3   1959-04-30  388.0
#   4   1959-05-31  396.0
#   ..         ...    ...
#   723 2019-04-30  327.0
#   724 2019-05-31  315.0
#   725 2019-06-30  308.0
#   726 2019-07-31  319.0
#   727 2019-08-31  319.0
#
#   [728 rows x 2 columns]},
#  {'name': 'fred_md_dataset_T50',
#   'serie':      Timestamp      Value
#   0   1959-01-31   14716.48
#   1   1959-02-28   15400.25
#   2   1959-03-31   15745.42
#   3   1959-04-30   15919.42
#   4   1959-05-31   15248.82
#   ..         ...        ...
#   723 2019-04-30  246609.00
#   724 2019-05-31  240923.00
#   725 2019-06-30  245231.00
#   726 2019-07-31  250216.00
#   727 2019-08-31  250670.00
#
#   [728 rows x 2 columns]},
#  {'name': 'fred_md_dataset_T51',
#   'serie':      Timestamp       Value
#   0   1959-01-31    42620.35
#   1   1959-02-28    43677.15
#   2   1959-03-31    44781.65
#   3   1959-04-30    45522.75
#   4   1959-05-31    45384.45
#   ..         ...         ...
#   723 2019-04-30  1177382.00
#   724 2019-05-31  1168212.00
#   725 2019-06-30  1160974.00
#   726 2019-07-31  1161613.00
#   727 2019-08-31  1162330.00
#
#   [728 rows x 2 columns]},
#  {'name': 'fred_md_dataset_T52',
#   'serie':      Timestamp   Value
#   0   1959-01-31   138.9
#   1   1959-02-28   139.4
#   2   1959-03-31   139.7
#   3   1959-04-30   139.7
#   4   1959-05-31   140.7
#   ..         ...     ...
#   723 2019-04-30  3776.7
#   724 2019-05-31  3784.1
#   725 2019-06-30  3824.1
#   726 2019-07-31  3852.2
#   727 2019-08-31  3839.7
#
#   [728 rows x 2 columns]},
#  {'name': 'fred_md_dataset_T53',
#   'serie':      Timestamp    Value
#   0   1959-01-31    286.6
#   1   1959-02-28    287.7
#   2   1959-03-31    289.2
#   3   1959-04-30    290.1
#   4   1959-05-31    292.2
#   ..         ...      ...
#   723 2019-04-30  14541.8
#   724 2019-05-31  14633.0
#   725 2019-06-30  14771.3
#   726 2019-07-31  14871.2
#   727 2019-08-31  14953.4
#
#   [728 rows x 2 columns]},
#  {'name': 'fred_md_dataset_T54',
#   'serie':      Timestamp   Value
#   0   1959-01-31   987.9
#   1   1959-02-28   992.1
#   2   1959-03-31   998.3
#   3   1959-04-30  1001.0
#   4   1959-05-31  1006.2
#   ..         ...     ...
#   723 2019-04-30  5703.6
#   724 2019-05-31  5734.9
#   725 2019-06-30  5785.7
#   726 2019-07-31  5805.4
#   727 2019-08-31  5834.3
#
#   [728 rows x 2 columns]},
#  {'name': 'fred_md_dataset_T55',
#   'serie':      Timestamp     Value
#   0   1959-01-31    38.756
#   1   1959-02-28    38.895
#   2   1959-03-31    38.896
#   3   1959-04-30    39.009
#   4   1959-05-31    39.089
#   ..         ...       ...
#   723 2019-04-30  3314.002
#   724 2019-05-31  3265.454
#   725 2019-06-30  3294.404
#   726 2019-07-31  3271.690
#   727 2019-08-31  3290.319
#
#   [728 rows x 2 columns]},
#  {'name': 'fred_md_dataset_T56',
#   'serie':      Timestamp     Value
#   0   1959-01-31    18.889
#   1   1959-02-28    18.570
#   2   1959-03-31    18.431
#   3   1959-04-30    18.678
#   4   1959-05-31    18.552
#   ..         ...       ...
#   723 2019-04-30  1623.904
#   724 2019-05-31  1576.309
#   725 2019-06-30  1601.309
#   726 2019-07-31  1578.615
#   727 2019-08-31  1586.844
#
#   [728 rows x 2 columns]},
#  {'name': 'fred_md_dataset_T57',
#   'serie':      Timestamp      Value
#   0   1959-01-31    18338.0
#   1   1959-02-28    18065.0
#   2   1959-03-31    17832.0
#   3   1959-04-30    17986.0
#   4   1959-05-31    17811.0
#   ..         ...        ...
#   723 2019-04-30  1623875.0
#   724 2019-05-31  1576254.0
#   725 2019-06-30  1601229.0
#   726 2019-07-31  1578495.0
#   727 2019-08-31  1586727.0
#
#   [728 rows x 2 columns]},
#  {'name': 'fred_md_dataset_T58',
#   'serie':      Timestamp      Value
#   0   1959-01-31    35.2130
#   1   1959-02-28    35.2201
#   2   1959-03-31    35.1304
#   3   1959-04-30    35.5581
#   4   1959-05-31    36.3064
#   ..         ...        ...
#   723 2019-04-30  2342.6845
#   724 2019-05-31  2345.4494
#   725 2019-06-30  2350.8796
#   726 2019-07-31  2351.5113
#   727 2019-08-31  2362.6830
#
#   [728 rows x 2 columns]},
#  {'name': 'fred_md_dataset_T59',
#   'serie':      Timestamp      Value
#   0   1959-01-31    24.9242
#   1   1959-02-28    25.2270
#   2   1959-03-31    25.4218
#   3   1959-04-30    25.7261
#   4   1959-05-31    26.0187
#   ..         ...        ...
#   723 2019-04-30  4475.6051
#   724 2019-05-31  4493.4510
#   725 2019-06-30  4505.6402
#   726 2019-07-31  4513.9242
#   727 2019-08-31  4521.9054
#
#   [728 rows x 2 columns]},
#  {'name': 'fred_md_dataset_T60',
#   'serie':      Timestamp    Value
#   0   1959-01-31    55.62
#   1   1959-02-28    54.77
#   2   1959-03-31    56.16
#   3   1959-04-30    57.10
#   4   1959-05-31    57.96
#   ..         ...      ...
#   723 2019-04-30  2903.80
#   724 2019-05-31  2854.71
#   725 2019-06-30  2890.17
#   726 2019-07-31  2996.11
#   727 2019-08-31  2897.50
#
#   [728 rows x 2 columns]},
#  {'name': 'fred_md_dataset_T61',
#   'serie':      Timestamp    Value
#   0   1959-01-31    59.30
#   1   1959-02-28    58.33
#   2   1959-03-31    59.79
#   3   1959-04-30    60.92
#   4   1959-05-31    62.09
#   ..         ...      ...
#   723 2019-04-30  3930.11
#   724 2019-05-31  3847.83
#   725 2019-06-30  3899.41
#   726 2019-07-31  4050.47
#   727 2019-08-31  3915.48
#
#   [728 rows x 2 columns]},
#  {'name': 'fred_md_dataset_T62',
#   'serie':      Timestamp  Value
#   0   1959-01-31   2.48
#   1   1959-02-28   2.43
#   2   1959-03-31   2.80
#   3   1959-04-30   2.96
#   4   1959-05-31   2.90
#   ..         ...    ...
#   723 2019-04-30   2.42
#   724 2019-05-31   2.39
#   725 2019-06-30   2.38
#   726 2019-07-31   2.40
#   727 2019-08-31   2.13
#
#   [728 rows x 2 columns]},
#  {'name': 'fred_md_dataset_T63',
#   'serie':      Timestamp  Value
#   0   1959-01-31   3.30
#   1   1959-02-28   3.26
#   2   1959-03-31   3.35
#   3   1959-04-30   3.42
#   4   1959-05-31   3.56
#   ..         ...    ...
#   723 2019-04-30   2.47
#   724 2019-05-31   2.44
#   725 2019-06-30   2.30
#   726 2019-07-31   2.22
#   727 2019-08-31   2.06
#
#   [728 rows x 2 columns]},
#  {'name': 'fred_md_dataset_T64',
#   'serie':      Timestamp  Value
#   0   1959-01-31   2.82
#   1   1959-02-28   2.70
#   2   1959-03-31   2.80
#   3   1959-04-30   2.95
#   4   1959-05-31   2.84
#   ..         ...    ...
#   723 2019-04-30   2.38
#   724 2019-05-31   2.35
#   725 2019-06-30   2.17
#   726 2019-07-31   2.10
#   727 2019-08-31   1.95
#
#   [728 rows x 2 columns]},
#  {'name': 'fred_md_dataset_T65',
#   'serie':      Timestamp  Value
#   0   1959-01-31   3.09
#   1   1959-02-28   3.13
#   2   1959-03-31   3.13
#   3   1959-04-30   3.27
#   4   1959-05-31   3.33
#   ..         ...    ...
#   723 2019-04-30   2.39
#   724 2019-05-31   2.35
#   725 2019-06-30   2.11
#   726 2019-07-31   2.03
#   727 2019-08-31   1.88
#
#   [728 rows x 2 columns]},
#  {'name': 'fred_md_dataset_T66',
#   'serie':      Timestamp  Value
#   0   1959-01-31   3.36
#   1   1959-02-28   3.54
#   2   1959-03-31   3.61
#   3   1959-04-30   3.72
#   4   1959-05-31   3.96
#   ..         ...    ...
#   723 2019-04-30   2.42
#   724 2019-05-31   2.34
#   725 2019-06-30   2.00
#   726 2019-07-31   1.96
#   727 2019-08-31   1.77
#
#   [728 rows x 2 columns]},
#  {'name': 'fred_md_dataset_T67',
#   'serie':      Timestamp  Value
#   0   1959-01-31   4.01
#   1   1959-02-28   3.96
#   2   1959-03-31   3.99
#   3   1959-04-30   4.12
#   4   1959-05-31   4.35
#   ..         ...    ...
#   723 2019-04-30   2.33
#   724 2019-05-31   2.19
#   725 2019-06-30   1.83
#   726 2019-07-31   1.83
#   727 2019-08-31   1.49
#
#   [728 rows x 2 columns]},
#  {'name': 'fred_md_dataset_T68',
#   'serie':      Timestamp  Value
#   0   1959-01-31   4.02
#   1   1959-02-28   3.96
#   2   1959-03-31   3.99
#   3   1959-04-30   4.12
#   4   1959-05-31   4.31
#   ..         ...    ...
#   723 2019-04-30   2.53
#   724 2019-05-31   2.40
#   725 2019-06-30   2.07
#   726 2019-07-31   2.06
#   727 2019-08-31   1.63
#
#   [728 rows x 2 columns]},
#  {'name': 'fred_md_dataset_T69',
#   'serie':      Timestamp  Value
#   0   1959-01-31   4.12
#   1   1959-02-28   4.14
#   2   1959-03-31   4.13
#   3   1959-04-30   4.23
#   4   1959-05-31   4.37
#   ..         ...    ...
#   723 2019-04-30   3.69
#   724 2019-05-31   3.67
#   725 2019-06-30   3.42
#   726 2019-07-31   3.29
#   727 2019-08-31   2.98
#
#   [728 rows x 2 columns]},
#  {'name': 'fred_md_dataset_T70',
#   'serie':      Timestamp  Value
#   0   1959-01-31   4.87
#   1   1959-02-28   4.89
#   2   1959-03-31   4.85
#   3   1959-04-30   4.86
#   4   1959-05-31   4.96
#   ..         ...    ...
#   723 2019-04-30   4.70
#   724 2019-05-31   4.63
#   725 2019-06-30   4.46
#   726 2019-07-31   4.28
#   727 2019-08-31   3.87
#
#   [728 rows x 2 columns]},
#  {'name': 'fred_md_dataset_T71',
#   'serie':      Timestamp  Value
#   0   1959-01-31   0.82
#   1   1959-02-28   0.83
#   2   1959-03-31   0.55
#   3   1959-04-30   0.46
#   4   1959-05-31   0.66
#   ..         ...    ...
#   723 2019-04-30   0.05
#   724 2019-05-31   0.05
#   725 2019-06-30  -0.08
#   726 2019-07-31  -0.18
#   727 2019-08-31  -0.07
#
#   [728 rows x 2 columns]},
#  {'name': 'fred_md_dataset_T72',
#   'serie':      Timestamp  Value
#   0   1959-01-31   0.34
#   1   1959-02-28   0.27
#   2   1959-03-31   0.00
#   3   1959-04-30  -0.01
#   4   1959-05-31  -0.06
#   ..         ...    ...
#   723 2019-04-30  -0.04
#   724 2019-05-31  -0.04
#   725 2019-06-30  -0.21
#   726 2019-07-31  -0.30
#   727 2019-08-31  -0.17
#
#   [728 rows x 2 columns]},
#  {'name': 'fred_md_dataset_T73',
#   'serie':      Timestamp  Value
#   0   1959-01-31   0.61
#   1   1959-02-28   0.70
#   2   1959-03-31   0.33
#   3   1959-04-30   0.31
#   4   1959-05-31   0.43
#   ..         ...    ...
#   723 2019-04-30  -0.03
#   724 2019-05-31  -0.04
#   725 2019-06-30  -0.27
#   726 2019-07-31  -0.37
#   727 2019-08-31  -0.24
#
#   [728 rows x 2 columns]},
#  {'name': 'fred_md_dataset_T74',
#   'serie':      Timestamp  Value
#   0   1959-01-31   0.88
#   1   1959-02-28   1.11
#   2   1959-03-31   0.81
#   3   1959-04-30   0.76
#   4   1959-05-31   1.06
#   ..         ...    ...
#   723 2019-04-30   0.00
#   724 2019-05-31  -0.05
#   725 2019-06-30  -0.38
#   726 2019-07-31  -0.44
#   727 2019-08-31  -0.35
#
#   [728 rows x 2 columns]},
#  {'name': 'fred_md_dataset_T75',
#   'serie':      Timestamp  Value
#   0   1959-01-31   1.53
#   1   1959-02-28   1.53
#   2   1959-03-31   1.19
#   3   1959-04-30   1.16
#   4   1959-05-31   1.45
#   ..         ...    ...
#   723 2019-04-30  -0.09
#   724 2019-05-31  -0.20
#   725 2019-06-30  -0.56
#   726 2019-07-31  -0.57
#   727 2019-08-31  -0.63
#
#   [728 rows x 2 columns]},
#  {'name': 'fred_md_dataset_T76',
#   'serie':      Timestamp  Value
#   0   1959-01-31   1.54
#   1   1959-02-28   1.53
#   2   1959-03-31   1.19
#   3   1959-04-30   1.16
#   4   1959-05-31   1.41
#   ..         ...    ...
#   723 2019-04-30   0.11
#   724 2019-05-31   0.01
#   725 2019-06-30  -0.31
#   726 2019-07-31  -0.34
#   727 2019-08-31  -0.49
#
#   [728 rows x 2 columns]},
#  {'name': 'fred_md_dataset_T77',
#   'serie':      Timestamp  Value
#   0   1959-01-31   1.64
#   1   1959-02-28   1.71
#   2   1959-03-31   1.33
#   3   1959-04-30   1.27
#   4   1959-05-31   1.47
#   ..         ...    ...
#   723 2019-04-30   1.27
#   724 2019-05-31   1.28
#   725 2019-06-30   1.04
#   726 2019-07-31   0.89
#   727 2019-08-31   0.86
#
#   [728 rows x 2 columns]},
#  {'name': 'fred_md_dataset_T78',
#   'serie':      Timestamp  Value
#   0   1959-01-31   2.39
#   1   1959-02-28   2.46
#   2   1959-03-31   2.05
#   3   1959-04-30   1.90
#   4   1959-05-31   2.06
#   ..         ...    ...
#   723 2019-04-30   2.28
#   724 2019-05-31   2.24
#   725 2019-06-30   2.08
#   726 2019-07-31   1.88
#   727 2019-08-31   1.75
#
#   [728 rows x 2 columns]},
#  {'name': 'fred_md_dataset_T79',
#   'serie':      Timestamp   Value
#   0   1959-01-31  4.3122
#   1   1959-02-28  4.3133
#   2   1959-03-31  4.3228
#   3   1959-04-30  4.3226
#   4   1959-05-31  4.3228
#   ..         ...     ...
#   723 2019-04-30  1.0084
#   724 2019-05-31  1.0107
#   725 2019-06-30  0.9880
#   726 2019-07-31  0.9880
#   727 2019-08-31  0.9787
#
#   [728 rows x 2 columns]},
#  {'name': 'fred_md_dataset_T80',
#   'serie':      Timestamp     Value
#   0   1959-01-31  359.8417
#   1   1959-02-28  359.8417
#   2   1959-03-31  359.8417
#   3   1959-04-30  359.8417
#   4   1959-05-31  359.8417
#   ..         ...       ...
#   723 2019-04-30  111.6414
#   724 2019-05-31  109.9714
#   725 2019-06-30  108.0685
#   726 2019-07-31  108.2864
#   727 2019-08-31  106.1886
#
#   [728 rows x 2 columns]},
#  {'name': 'fred_md_dataset_T81',
#   'serie':      Timestamp   Value
#   0   1959-01-31  2.8065
#   1   1959-02-28  2.8093
#   2   1959-03-31  2.8127
#   3   1959-04-30  2.8165
#   4   1959-05-31  2.8145
#   ..         ...     ...
#   723 2019-04-30  1.3029
#   724 2019-05-31  1.2855
#   725 2019-06-30  1.2675
#   726 2019-07-31  1.2461
#   727 2019-08-31  1.2160
#
#   [728 rows x 2 columns]},
#  {'name': 'fred_md_dataset_T82',
#   'serie':      Timestamp   Value
#   0   1959-01-31  0.9671
#   1   1959-02-28  0.9748
#   2   1959-03-31  0.9698
#   3   1959-04-30  0.9636
#   4   1959-05-31  0.9630
#   ..         ...     ...
#   723 2019-04-30  1.3378
#   724 2019-05-31  1.3460
#   725 2019-06-30  1.3289
#   726 2019-07-31  1.3105
#   727 2019-08-31  1.3273
#
#   [728 rows x 2 columns]},
#  {'name': 'fred_md_dataset_T83',
#   'serie':      Timestamp  Value
#   0   1959-01-31   33.1
#   1   1959-02-28   33.2
#   2   1959-03-31   33.2
#   3   1959-04-30   33.2
#   4   1959-05-31   33.3
#   ..         ...    ...
#   723 2019-04-30  207.0
#   724 2019-05-31  206.4
#   725 2019-06-30  205.5
#   726 2019-07-31  206.7
#   727 2019-08-31  205.5
#
#   [728 rows x 2 columns]},
#  {'name': 'fred_md_dataset_T84',
#   'serie':      Timestamp  Value
#   0   1959-01-31   33.4
#   1   1959-02-28   33.4
#   2   1959-03-31   33.3
#   3   1959-04-30   33.4
#   4   1959-05-31   33.3
#   ..         ...    ...
#   723 2019-04-30  219.6
#   724 2019-05-31  218.6
#   725 2019-06-30  217.1
#   726 2019-07-31  218.7
#   727 2019-08-31  217.0
#
#   [728 rows x 2 columns]},
#  {'name': 'fred_md_dataset_T85',
#   'serie':      Timestamp  Value
#   0   1959-01-31   30.6
#   1   1959-02-28   30.7
#   2   1959-03-31   30.7
#   3   1959-04-30   30.7
#   4   1959-05-31   30.9
#   ..         ...    ...
#   723 2019-04-30  200.6
#   724 2019-05-31  199.9
#   725 2019-06-30  197.8
#   726 2019-07-31  198.2
#   727 2019-08-31  196.9
#
#   [728 rows x 2 columns]},
#  {'name': 'fred_md_dataset_T86',
#   'serie':      Timestamp  Value
#   0   1959-01-31   31.6
#   1   1959-02-28   31.4
#   2   1959-03-31   31.5
#   3   1959-04-30   31.7
#   4   1959-05-31   31.5
#   ..         ...    ...
#   723 2019-04-30  192.2
#   724 2019-05-31  184.9
#   725 2019-06-30  178.8
#   726 2019-07-31  181.7
#   727 2019-08-31  179.8
#
#   [728 rows x 2 columns]},
#  {'name': 'fred_md_dataset_T87',
#   'serie':      Timestamp  Value
#   0   1959-01-31   3.00
#   1   1959-02-28   3.00
#   2   1959-03-31   2.97
#   3   1959-04-30   2.97
#   4   1959-05-31   2.97
#   ..         ...    ...
#   723 2019-04-30  63.86
#   724 2019-05-31  60.83
#   725 2019-06-30  54.66
#   726 2019-07-31  57.35
#   727 2019-08-31  54.81
#
#   [728 rows x 2 columns]},
#  {'name': 'fred_md_dataset_T88',
#   'serie':      Timestamp  Value
#   0   1959-01-31   32.5
#   1   1959-02-28   32.5
#   2   1959-03-31   32.9
#   3   1959-04-30   32.7
#   4   1959-05-31   32.9
#   ..         ...    ...
#   723 2019-04-30  192.1
#   724 2019-05-31  187.0
#   725 2019-06-30  185.3
#   726 2019-07-31  188.7
#   727 2019-08-31  185.1
#
#   [728 rows x 2 columns]},
#  {'name': 'fred_md_dataset_T89',
#   'serie':      Timestamp    Value
#   0   1959-01-31   29.010
#   1   1959-02-28   29.000
#   2   1959-03-31   28.970
#   3   1959-04-30   28.980
#   4   1959-05-31   29.040
#   ..         ...      ...
#   723 2019-04-30  254.958
#   724 2019-05-31  255.155
#   725 2019-06-30  255.305
#   726 2019-07-31  256.161
#   727 2019-08-31  256.300
#
#   [728 rows x 2 columns]},
#  {'name': 'fred_md_dataset_T90',
#   'serie':      Timestamp    Value
#   0   1959-01-31   44.800
#   1   1959-02-28   44.700
#   2   1959-03-31   44.700
#   3   1959-04-30   44.800
#   4   1959-05-31   44.900
#   ..         ...      ...
#   723 2019-04-30  122.968
#   724 2019-05-31  122.908
#   725 2019-06-30  124.297
#   726 2019-07-31  124.843
#   727 2019-08-31  125.108
#
#   [728 rows x 2 columns]},
#  {'name': 'fred_md_dataset_T91',
#   'serie':      Timestamp    Value
#   0   1959-01-31   29.300
#   1   1959-02-28   29.400
#   2   1959-03-31   29.600
#   3   1959-04-30   29.700
#   4   1959-05-31   29.700
#   ..         ...      ...
#   723 2019-04-30  211.904
#   724 2019-05-31  211.325
#   725 2019-06-30  209.884
#   726 2019-07-31  211.551
#   727 2019-08-31  210.345
#
#   [728 rows x 2 columns]},
#  {'name': 'fred_md_dataset_T92',
#   'serie':      Timestamp    Value
#   0   1959-01-31   21.100
#   1   1959-02-28   21.200
#   2   1959-03-31   21.300
#   3   1959-04-30   21.300
#   4   1959-05-31   21.400
#   ..         ...      ...
#   723 2019-04-30  492.459
#   724 2019-05-31  493.908
#   725 2019-06-30  495.328
#   726 2019-07-31  497.702
#   727 2019-08-31  501.385
#
#   [728 rows x 2 columns]},
#  {'name': 'fred_md_dataset_T93',
#   'serie':      Timestamp    Value
#   0   1959-01-31   33.300
#   1   1959-02-28   33.300
#   2   1959-03-31   33.200
#   3   1959-04-30   33.200
#   4   1959-05-31   33.300
#   ..         ...      ...
#   723 2019-04-30  185.664
#   724 2019-05-31  185.635
#   725 2019-06-30  185.254
#   726 2019-07-31  186.014
#   727 2019-08-31  185.541
#
#   [728 rows x 2 columns]},
#  {'name': 'fred_md_dataset_T94',
#   'serie':      Timestamp    Value
#   0   1959-01-31   38.100
#   1   1959-02-28   38.100
#   2   1959-03-31   38.300
#   3   1959-04-30   38.300
#   4   1959-05-31   38.400
#   ..         ...      ...
#   723 2019-04-30  104.504
#   724 2019-05-31  104.270
#   725 2019-06-30  104.758
#   726 2019-07-31  105.042
#   727 2019-08-31  105.255
#
#   [728 rows x 2 columns]},
#  {'name': 'fred_md_dataset_T95',
#   'serie':      Timestamp    Value
#   0   1959-01-31   22.900
#   1   1959-02-28   23.000
#   2   1959-03-31   23.000
#   3   1959-04-30   23.100
#   4   1959-05-31   23.200
#   ..         ...      ...
#   723 2019-04-30  323.286
#   724 2019-05-31  323.702
#   725 2019-06-30  324.408
#   726 2019-07-31  325.348
#   727 2019-08-31  326.116
#
#   [728 rows x 2 columns]},
#  {'name': 'fred_md_dataset_T96',
#   'serie':      Timestamp    Value
#   0   1959-01-31   28.900
#   1   1959-02-28   28.900
#   2   1959-03-31   28.900
#   3   1959-04-30   29.000
#   4   1959-05-31   29.100
#   ..         ...      ...
#   723 2019-04-30  254.540
#   724 2019-05-31  254.664
#   725 2019-06-30  254.820
#   726 2019-07-31  255.795
#   727 2019-08-31  255.956
#
#   [728 rows x 2 columns]},
#  {'name': 'fred_md_dataset_T97',
#   'serie':      Timestamp    Value
#   0   1959-01-31   30.700
#   1   1959-02-28   30.700
#   2   1959-03-31   30.700
#   3   1959-04-30   30.700
#   4   1959-05-31   30.700
#   ..         ...      ...
#   723 2019-04-30  233.891
#   724 2019-05-31  233.879
#   725 2019-06-30  233.724
#   726 2019-07-31  234.582
#   727 2019-08-31  234.595
#
#   [728 rows x 2 columns]},
#  {'name': 'fred_md_dataset_T98',
#   'serie':      Timestamp    Value
#   0   1959-01-31   29.600
#   1   1959-02-28   29.600
#   2   1959-03-31   29.600
#   3   1959-04-30   29.600
#   4   1959-05-31   29.600
#   ..         ...      ...
#   723 2019-04-30  243.558
#   724 2019-05-31  243.697
#   725 2019-06-30  243.787
#   726 2019-07-31  244.571
#   727 2019-08-31  244.544
#
#   [728 rows x 2 columns]},
#  {'name': 'fred_md_dataset_T99',
#   'serie':      Timestamp    Value
#   0   1959-01-31   16.074
#   1   1959-02-28   16.089
#   2   1959-03-31   16.100
#   3   1959-04-30   16.132
#   4   1959-05-31   16.140
#   ..         ...      ...
#   723 2019-04-30  109.403
#   724 2019-05-31  109.511
#   725 2019-06-30  109.653
#   726 2019-07-31  109.914
#   727 2019-08-31  109.950
#
#   [728 rows x 2 columns]},
#  {'name': 'fred_md_dataset_T100',
#   'serie':      Timestamp   Value
#   0   1959-01-31  56.918
#   1   1959-02-28  56.951
#   2   1959-03-31  57.022
#   3   1959-04-30  57.080
#   4   1959-05-31  57.175
#   ..         ...     ...
#   723 2019-04-30  86.490
#   724 2019-05-31  86.536
#   725 2019-06-30  86.953
#   726 2019-07-31  86.575
#   727 2019-08-31  86.394
#
#   [728 rows x 2 columns]},
#  {'name': 'fred_md_dataset_T101',
#   'serie':      Timestamp   Value
#   0   1959-01-31  17.791
#   1   1959-02-28  17.798
#   2   1959-03-31  17.785
#   3   1959-04-30  17.796
#   4   1959-05-31  17.777
#   ..         ...     ...
#   723 2019-04-30  99.460
#   724 2019-05-31  99.534
#   725 2019-06-30  99.115
#   726 2019-07-31  99.580
#   727 2019-08-31  99.278
#
#   [728 rows x 2 columns]},
#  {'name': 'fred_md_dataset_T102',
#   'serie':      Timestamp    Value
#   0   1959-01-31   11.358
#   1   1959-02-28   11.375
#   2   1959-03-31   11.395
#   3   1959-04-30   11.436
#   4   1959-05-31   11.454
#   ..         ...      ...
#   723 2019-04-30  116.951
#   724 2019-05-31  117.084
#   725 2019-06-30  117.364
#   726 2019-07-31  117.684
#   727 2019-08-31  117.885
#
#   [728 rows x 2 columns]},
#  {'name': 'fred_md_dataset_T103',
#   'serie':      Timestamp  Value
#   0   1959-01-31   2.13
#   1   1959-02-28   2.14
#   2   1959-03-31   2.15
#   3   1959-04-30   2.16
#   4   1959-05-31   2.17
#   ..         ...    ...
#   723 2019-04-30  24.59
#   724 2019-05-31  24.66
#   725 2019-06-30  24.72
#   726 2019-07-31  24.73
#   727 2019-08-31  24.81
#
#   [728 rows x 2 columns]},
#  {'name': 'fred_md_dataset_T104',
#   'serie':      Timestamp  Value
#   0   1959-01-31   2.45
#   1   1959-02-28   2.46
#   2   1959-03-31   2.45
#   3   1959-04-30   2.47
#   4   1959-05-31   2.48
#   ..         ...    ...
#   723 2019-04-30  28.42
#   724 2019-05-31  28.44
#   725 2019-06-30  28.46
#   726 2019-07-31  28.42
#   727 2019-08-31  28.54
#
#   [728 rows x 2 columns]},
#  {'name': 'fred_md_dataset_T105',
#   'serie':      Timestamp  Value
#   0   1959-01-31   2.04
#   1   1959-02-28   2.05
#   2   1959-03-31   2.07
#   3   1959-04-30   2.08
#   4   1959-05-31   2.08
#   ..         ...    ...
#   723 2019-04-30  21.96
#   724 2019-05-31  22.04
#   725 2019-06-30  22.13
#   726 2019-07-31  22.19
#   727 2019-08-31  22.23
#
#   [728 rows x 2 columns]},
#  {'name': 'fred_md_dataset_T106',
#   'serie':      Timestamp    Value
#   0   1959-01-31    274.9
#   1   1959-02-28    276.0
#   2   1959-03-31    277.4
#   3   1959-04-30    278.1
#   4   1959-05-31    280.1
#   ..         ...      ...
#   723 2019-04-30  15874.9
#   724 2019-05-31  15995.9
#   725 2019-06-30  16181.6
#   726 2019-07-31  16350.0
#   727 2019-08-31  16474.3
#
#   [728 rows x 2 columns]},
#  {'name': 'fred_md_dataset_T107',
#   'serie':      Timestamp      Value
#   0   1959-01-31    84.2043
#   1   1959-02-28    83.5280
#   2   1959-03-31    81.6405
#   3   1959-04-30    81.8099
#   4   1959-05-31    80.7315
#   ..         ...        ...
#   723 2019-04-30  3608.8391
#   724 2019-05-31  3622.2532
#   725 2019-06-30  3651.3512
#   726 2019-07-31  3673.9513
#   727 2019-08-31  3725.4103
#
#   [728 rows x 2 columns]}]

# %%
files = list_files('./files', '.csv')

# %%
files
# Out:
# ['./files/fred_md_dataset_T10.csv',
#  './files/fred_md_dataset_T12.csv',
#  './files/fred_md_dataset_T13.csv',
#  './files/fred_md_dataset_T15.csv',
#  './files/fred_md_dataset_T17.csv',
#  './files/fred_md_dataset_T19.csv',
#  './files/fred_md_dataset_T21.csv',
#  './files/fred_md_dataset_T18.csv',
#  './files/fred_md_dataset_T20.csv',
#  './files/bitcoin_dataset_with_missing_values_difficulty.csv',
#  './files/bitcoin_dataset_with_missing_values_sent_addresses.csv',
#  './files/bitcoin_dataset_with_missing_values_send_usd.csv',
#  './files/bitcoin_dataset_with_missing_values_market_cap.csv',
#  './files/bitcoin_dataset_with_missing_values_confirmation_time.csv',
#  './files/bitcoin_dataset_with_missing_values_transactions.csv',
#  './files/bitcoin_dataset_with_missing_values_median_transaction_size.csv',
#  './files/bitcoin_dataset_with_missing_values_mining_profitability.csv',
#  './files/bitcoin_dataset_with_missing_values_fee_reward.csv',
#  './files/bitcoin_dataset_with_missing_values_top_100_percent.csv',
#  './files/bitcoin_dataset_with_missing_values_median_transaction_value.csv',
#  './files/bitcoin_dataset_with_missing_values_av_transaction_value.csv',
#  './files/bitcoin_dataset_with_missing_values_block_size.csv',
#  './files/bitcoin_dataset_with_missing_values_hashrate.csv',
#  './files/bitcoin_dataset_with_missing_values_active_addresses.csv',
#  './files/bitcoin_dataset_with_missing_values_google_trends.csv',
#  './files/bitcoin_dataset_with_missing_values_tweets.csv',
#  './files/bitcoin_dataset_with_missing_values_price.csv',
#  './files/bitcoin_dataset_without_missing_values_difficulty.csv',
#  './files/bitcoin_dataset_without_missing_values_sent_addresses.csv',
#  './files/bitcoin_dataset_without_missing_values_send_usd.csv',
#  './files/bitcoin_dataset_without_missing_values_market_cap.csv',
#  './files/bitcoin_dataset_without_missing_values_confirmation_time.csv',
#  './files/bitcoin_dataset_without_missing_values_transactions.csv',
#  './files/bitcoin_dataset_without_missing_values_median_transaction_size.csv',
#  './files/bitcoin_dataset_without_missing_values_mining_profitability.csv',
#  './files/bitcoin_dataset_without_missing_values_fee_reward.csv',
#  './files/bitcoin_dataset_without_missing_values_top_100_percent.csv',
#  './files/bitcoin_dataset_without_missing_values_median_transaction_value.csv',
#  './files/bitcoin_dataset_without_missing_values_av_transaction_value.csv',
#  './files/bitcoin_dataset_without_missing_values_block_size.csv',
#  './files/bitcoin_dataset_without_missing_values_hashrate.csv',
#  './files/bitcoin_dataset_without_missing_values_active_addresses.csv',
#  './files/bitcoin_dataset_without_missing_values_google_trends.csv',
#  './files/bitcoin_dataset_without_missing_values_tweets.csv',
#  './files/bitcoin_dataset_without_missing_values_price.csv',
#  './files/fred_md_dataset_T1.csv',
#  './files/fred_md_dataset_T2.csv',
#  './files/fred_md_dataset_T3.csv',
#  './files/fred_md_dataset_T4.csv',
#  './files/fred_md_dataset_T5.csv',
#  './files/fred_md_dataset_T6.csv',
#  './files/fred_md_dataset_T7.csv',
#  './files/fred_md_dataset_T8.csv',
#  './files/fred_md_dataset_T9.csv',
#  './files/fred_md_dataset_T11.csv',
#  './files/fred_md_dataset_T14.csv',
#  './files/fred_md_dataset_T16.csv',
#  './files/fred_md_dataset_T22.csv',
#  './files/fred_md_dataset_T23.csv',
#  './files/fred_md_dataset_T24.csv',
#  './files/fred_md_dataset_T25.csv',
#  './files/fred_md_dataset_T26.csv',
#  './files/fred_md_dataset_T27.csv',
#  './files/fred_md_dataset_T28.csv',
#  './files/fred_md_dataset_T29.csv',
#  './files/fred_md_dataset_T30.csv',
#  './files/fred_md_dataset_T31.csv',
#  './files/fred_md_dataset_T32.csv',
#  './files/fred_md_dataset_T33.csv',
#  './files/fred_md_dataset_T34.csv',
#  './files/fred_md_dataset_T35.csv',
#  './files/fred_md_dataset_T36.csv',
#  './files/fred_md_dataset_T37.csv',
#  './files/fred_md_dataset_T38.csv',
#  './files/fred_md_dataset_T39.csv',
#  './files/fred_md_dataset_T40.csv',
#  './files/fred_md_dataset_T41.csv',
#  './files/fred_md_dataset_T42.csv',
#  './files/fred_md_dataset_T43.csv',
#  './files/fred_md_dataset_T44.csv',
#  './files/fred_md_dataset_T45.csv',
#  './files/fred_md_dataset_T46.csv',
#  './files/fred_md_dataset_T47.csv',
#  './files/fred_md_dataset_T48.csv',
#  './files/fred_md_dataset_T49.csv',
#  './files/fred_md_dataset_T50.csv',
#  './files/fred_md_dataset_T51.csv',
#  './files/fred_md_dataset_T52.csv',
#  './files/fred_md_dataset_T53.csv',
#  './files/fred_md_dataset_T54.csv',
#  './files/fred_md_dataset_T55.csv',
#  './files/fred_md_dataset_T56.csv',
#  './files/fred_md_dataset_T57.csv',
#  './files/fred_md_dataset_T58.csv',
#  './files/fred_md_dataset_T59.csv',
#  './files/fred_md_dataset_T60.csv',
#  './files/fred_md_dataset_T61.csv',
#  './files/fred_md_dataset_T62.csv',
#  './files/fred_md_dataset_T63.csv',
#  './files/fred_md_dataset_T64.csv',
#  './files/fred_md_dataset_T65.csv',
#  './files/fred_md_dataset_T66.csv',
#  './files/fred_md_dataset_T67.csv',
#  './files/fred_md_dataset_T68.csv',
#  './files/fred_md_dataset_T69.csv',
#  './files/fred_md_dataset_T70.csv',
#  './files/fred_md_dataset_T71.csv',
#  './files/fred_md_dataset_T72.csv',
#  './files/fred_md_dataset_T73.csv',
#  './files/fred_md_dataset_T74.csv',
#  './files/fred_md_dataset_T75.csv',
#  './files/fred_md_dataset_T76.csv',
#  './files/fred_md_dataset_T77.csv',
#  './files/fred_md_dataset_T78.csv',
#  './files/fred_md_dataset_T79.csv',
#  './files/fred_md_dataset_T80.csv',
#  './files/fred_md_dataset_T81.csv',
#  './files/fred_md_dataset_T82.csv',
#  './files/fred_md_dataset_T83.csv',
#  './files/fred_md_dataset_T84.csv',
#  './files/fred_md_dataset_T85.csv',
#  './files/fred_md_dataset_T86.csv',
#  './files/fred_md_dataset_T87.csv',
#  './files/fred_md_dataset_T88.csv',
#  './files/fred_md_dataset_T89.csv',
#  './files/fred_md_dataset_T90.csv',
#  './files/fred_md_dataset_T91.csv',
#  './files/fred_md_dataset_T92.csv',
#  './files/fred_md_dataset_T93.csv',
#  './files/fred_md_dataset_T94.csv',
#  './files/fred_md_dataset_T95.csv',
#  './files/fred_md_dataset_T96.csv',
#  './files/fred_md_dataset_T97.csv',
#  './files/fred_md_dataset_T98.csv',
#  './files/fred_md_dataset_T99.csv',
#  './files/fred_md_dataset_T100.csv',
#  './files/fred_md_dataset_T101.csv',
#  './files/fred_md_dataset_T102.csv',
#  './files/fred_md_dataset_T103.csv',
#  './files/fred_md_dataset_T104.csv',
#  './files/fred_md_dataset_T105.csv',
#  './files/fred_md_dataset_T106.csv',
#  './files/fred_md_dataset_T107.csv']

# %%
testing_datasets = []
for file in files[:4]:
    testing_datasets.append({"file_name": file,
                            "format": "csv",
                            "time_col_index": 0,
                            "target_col_index": -1,
                            "exovar": False,})

# %%
testing_datasets
# Out:
# [{'file_name': './files/fred_md_dataset_T10.csv',
#   'format': 'csv',
#   'time_col_index': 0,
#   'target_col_index': -1,
#   'exovar': False},
#  {'file_name': './files/fred_md_dataset_T12.csv',
#   'format': 'csv',
#   'time_col_index': 0,
#   'target_col_index': -1,
#   'exovar': False},
#  {'file_name': './files/fred_md_dataset_T13.csv',
#   'format': 'csv',
#   'time_col_index': 0,
#   'target_col_index': -1,
#   'exovar': False},
#  {'file_name': './files/fred_md_dataset_T15.csv',
#   'format': 'csv',
#   'time_col_index': 0,
#   'target_col_index': -1,
#   'exovar': False}]

# %%
TEST_PERIOD=7

# %%
def prepare_dataset_forecast(dataset_info, test_period=TEST_PERIOD):
    if dataset_info["format"] == "csv":
        train_df = pd.read_csv(dataset_info["file_name"])
        time_col = train_df.columns[dataset_info["time_col_index"]]
        target_col = train_df.columns[dataset_info["target_col_index"]]
        train_df[time_col] = train_df[time_col].astype(str)
        train_df[target_col] = train_df[target_col].astype(float)
        train_data = []
        for value in train_df.iloc[:, [dataset_info["time_col_index"],
                                       dataset_info["target_col_index"]]].values:
            train_data.append(list(value))
    return train_data[:-test_period], train_data[-test_period:]

# %% [markdown]
# ## Logging Settings <a class="anchor" id="logging-bullet"></a>

# %%
LOG_RESULTS = True

# %%
user_name = getpass.getuser()

# %%
output_file_name = "./test_logs/test_logs_forecast_{}.csv".format(user_name)
print(output_file_name)

column_names = ["file_name", "model_request", "user", "time", "response", 
                "type", "metrics", "model", "test_data"]
log_df = pd.DataFrame(columns=column_names)
# Out:
# ./test_logs/test_logs_forecast_studio-lab-user.csv

# %% [markdown]
# ## Request <a class="anchor" id="requests-bullet"></a>

# %% [markdown]
# Define Model Request (optional)

# %%
# # Customized model request
# model_request = {
#     "type": "meta_lr",  # 'meta_wa'
#     "scorers": ["smape", "mape"],
#     "params": {
#         "preprocessors": [
#             {"type": "dartsimputer", "params": {"strategy": "mean"}},
#             # {'type': 'simpleimputer', 'params': {'strategy': 'mean'}},
#             {"type": "minmaxscaler"},
#         ],
#         "base_models": [
#             {"type": "darts_naive"},
#             {"type": "darts_seasonalnaive"},
#             {"type": "darts_autotheta"},
#             {"type": "darts_autoets"},
#             {"type": "darts_autoarima"},
#             #{"type": "darts_tbats"},
#             #{"type": "darts_linearregression"},
#             # {'type': 'darts_lightgbm'},
#             # {'type': 'darts_rnn'},
#         ],
#     },
# }

# %% [markdown]
# Load using JSON model request

# %%
file_path = 'model_request.json'
# For writing the model request to a json file
with open(file_path, 'r') as file:
    model_request = json.load(file)

# %% [markdown]
# Load using YAML model request

# %%
file_path = 'model_request.yaml'
# For reading the model request from a yaml file
with open(file_path, 'r') as file:
    model_request = yaml.safe_load(file)

# %%
with open("url.yaml", "r") as file:
    url_dict = yaml.safe_load(file)

# URL to our SYBIL AWS service
protocol = url_dict["protocol"]
host = url_dict["host"]
port = url_dict["port"]
endpoint = "train"

url = "%s://%s:%s/%s" % (protocol, host, str(port), endpoint)

# %%
for dataset in testing_datasets:
    train_data, test_data = prepare_dataset_forecast(dataset)
    api_json = {
        "data": train_data,
        "model": model_request,  # (optional) can be commented out
    }
    start_time = time.time()
    response = requests.post(url, json=api_json)
    exc_time = time.time() - start_time
    model_req = api_json["model"] if "model" in api_json.keys() else "default"
    new_row = pd.DataFrame(
        [
            {
                "file_name": dataset["file_name"],
                "model_request": model_req,
                "user": user_name,
                "time": exc_time,
                "response": response.status_code,
                "type": response.json()['type'],
                "metrics": response.json()['metrics'],
                "model": response.json()['model'],
                "test_data": test_data
            }
        ]
    )
    log_df = pd.concat([log_df, new_row], ignore_index=True)
    print(response)
# Out:
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>

# %%
log_df
# Out:
#                          file_name  \
# 0  ./files/fred_md_dataset_T10.csv
# 1  ./files/fred_md_dataset_T12.csv
# 2  ./files/fred_md_dataset_T13.csv
# 3  ./files/fred_md_dataset_T15.csv
#
#                                        model_request             user  \
# 0  {'type': 'meta_wa', 'scorers': ['mase', 'smape...  studio-lab-user
# 1  {'type': 'meta_wa', 'scorers': ['mase', 'smape...  studio-lab-user
# 2  {'type': 'meta_wa', 'scorers': ['mase', 'smape...  studio-lab-user
# 3  {'type': 'meta_wa', 'scorers': ['mase', 'smape...  studio-lab-user
#
#          time response     type  \
# 0  425.591252      200  meta_wa
# 1  351.685782      200  meta_wa
# 2  337.166843      200  meta_wa
# 3  358.119383      200  meta_wa
#
#                                              metrics  \
# 0  [{'type': 'mase', 'value': 3.2043658395515218}...
# 1  [{'type': 'mase', 'value': 15.75924537769056},...
# 2  [{'type': 'mase', 'value': 11.588277224010945}...
# 3  [{'type': 'mase', 'value': 4.928702326157349},...
#
#                                                model  \
# 0  AgEBCOPFGwAAABAAMgwXABgAAACS4QwAjKABAD+AAGVsaZ...
# 1  AgEBCJndGwAAABAAsQQXABgAAAAc1AwAZJwBAD+AAGVsaZ...
# 2  AgEBCGqoGwAAABAAFgsXABgAAABj9AwANKABAD+AAGVsaZ...
# 3  AgEBCO8OHAAAABAAr0YXABgAAAAO3wwA8Z0BAD+AAGVsaZ...
#
#                                            test_data
# 0  [[2019-02-28, 101.9729], [2019-03-31, 103.2309...
# 1  [[2019-02-28, 114.7969], [2019-03-31, 114.46],...
# 2  [[2019-02-28, 108.4955], [2019-03-31, 107.9445...
# 3  [[2019-02-28, 105.2961], [2019-03-31, 105.2392...

# %% [markdown]
# ## Forecast <a class="anchor" id="forecast-bullet"></a>

# %%
responses = []
for idx, row in log_df.iterrows():
    dates = list(np.array(row['test_data'])[:,0])
    model = row['model']
    api_json = {
                    'model': model,
                    'data': dates
                }
    endpoint = 'forecast'
    url = '%s://%s:%s/%s' % (protocol, host, str(port), endpoint)
    response = requests.post(url, json=api_json)
    responses.append(response.json()['data'])

# %%
log_df['forecast_data'] = responses

# %%
# Comparison of the results
for idx, row in log_df.iterrows():
    comparison_df = pd.DataFrame({'test':list(np.array(row['test_data'])[:,1]),
                'pred':list(np.array(row['forecast_data'])[:,1])})
    display(comparison_df)
# Out:
#        test                pred
# 0  101.9729  100.22488677617763
# 1  103.2309  100.97632436017685
# 2  100.9801  101.04775115235509
# 3  101.1794  101.07354799866387
# 4  101.4176  100.94843797345348
# 5  101.5514  101.01802786888923
# 6  101.8472  101.09479615135082
#        test                pred
# 0  114.7969  113.58359305210246
# 1    114.46  113.96570873841269
# 2  114.7893  114.03209610781323
# 3  114.6911  114.08126879199833
# 4  114.4141  114.11668889515323
# 5  114.2963  114.12719139888448
# 6  115.2718  114.17139902205956
#        test                pred
# 0  108.4955  106.80137312298976
# 1  107.9445  107.16871747951427
# 2  107.4001  107.15616449296186
# 3  107.2815  107.12695235107472
# 4  107.7241  107.07659542512644
# 5  107.2339  107.00914574279945
# 6  107.9056  107.02468748241502
#        test                pred
# 0  105.2961  104.23735029667486
# 1  105.2392  104.74988780770006
# 2  104.3399  104.89906941204042
# 3   104.462   104.8024484340046
# 4  105.0892  104.94673295041696
# 5   104.678  105.12352027742897
# 6  105.2156  105.04018159113797

# %%
comparison_df['test']
# Out:
# 0    105.2961
# 1    105.2392
# 2    104.3399
# 3     104.462
# 4    105.0892
# 5     104.678
# 6    105.2156
# Name: test, dtype: object

# %% [markdown]
# ## Save Results <a class="anchor" id="results-bullet"></a>

# %%
# Logs
log_df
# Out:
#                          file_name  \
# 0  ./files/fred_md_dataset_T10.csv
# 1  ./files/fred_md_dataset_T12.csv
# 2  ./files/fred_md_dataset_T13.csv
# 3  ./files/fred_md_dataset_T15.csv
#
#                                        model_request             user  \
# 0  {'type': 'meta_wa', 'scorers': ['mase', 'smape...  studio-lab-user
# 1  {'type': 'meta_wa', 'scorers': ['mase', 'smape...  studio-lab-user
# 2  {'type': 'meta_wa', 'scorers': ['mase', 'smape...  studio-lab-user
# 3  {'type': 'meta_wa', 'scorers': ['mase', 'smape...  studio-lab-user
#
#          time response     type  \
# 0  425.591252      200  meta_wa
# 1  351.685782      200  meta_wa
# 2  337.166843      200  meta_wa
# 3  358.119383      200  meta_wa
#
#                                              metrics  \
# 0  [{'type': 'mase', 'value': 3.2043658395515218}...
# 1  [{'type': 'mase', 'value': 15.75924537769056},...
# 2  [{'type': 'mase', 'value': 11.588277224010945}...
# 3  [{'type': 'mase', 'value': 4.928702326157349},...
#
#                                                model  \
# 0  AgEBCOPFGwAAABAAMgwXABgAAACS4QwAjKABAD+AAGVsaZ...
# 1  AgEBCJndGwAAABAAsQQXABgAAAAc1AwAZJwBAD+AAGVsaZ...
# 2  AgEBCGqoGwAAABAAFgsXABgAAABj9AwANKABAD+AAGVsaZ...
# 3  AgEBCO8OHAAAABAAr0YXABgAAAAO3wwA8Z0BAD+AAGVsaZ...
#
#                                            test_data  \
# 0  [[2019-02-28, 101.9729], [2019-03-31, 103.2309...
# 1  [[2019-02-28, 114.7969], [2019-03-31, 114.46],...
# 2  [[2019-02-28, 108.4955], [2019-03-31, 107.9445...
# 3  [[2019-02-28, 105.2961], [2019-03-31, 105.2392...
#
#                                        forecast_data
# 0  [[2019-02-28, 100.22488677617763], [2019-03-31...
# 1  [[2019-02-28, 113.58359305210246], [2019-03-31...
# 2  [[2019-02-28, 106.80137312298976], [2019-03-31...
# 3  [[2019-02-28, 104.23735029667486], [2019-03-31...

# %%
if LOG_RESULTS:
    if os.path.exists(output_file_name):
        existing_log_df = pd.read_csv(output_file_name)
        updated_df = pd.concat([existing_log_df, log_df], ignore_index=True)
    else:
        updated_df = log_df
    updated_df.to_csv(output_file_name, index=False)

# %%
log_df = pd.read_csv(output_file_name)

# %%
log_df
# Out:
#                                             file_name  \
# 0   https://github.com/ourownstory/neuralprophet-d...
# 1           ../datasets/air_quality/BeijingPM25_0.csv
# 2           ../datasets/energy/elecdemand_dataset.csv
# 3           ../datasets/climate/temp_anom_monthly.csv
# 4         ../datasets/climate/temp_anom_w_forcing.csv
# 5              ../datasets/climate/yosemite_temps.csv
# 6                 ../datasets/retail/retail_sales.csv
# 7   ../datasets/finance/Returns_short_interest_dat...
# 8                 ../datasets/retail/retail_sales.csv
# 9   ../datasets/finance/Returns_short_interest_dat...
# 10                    ./files/fred_md_dataset_T10.csv
# 11                    ./files/fred_md_dataset_T12.csv
# 12                    ./files/fred_md_dataset_T13.csv
# 13                    ./files/fred_md_dataset_T15.csv
#
#                                         model_request             user  \
# 0   {'type': 'meta_lr', 'scorers': ['smape', 'mape...  studio-lab-user
# 1   {'type': 'meta_lr', 'scorers': ['smape', 'mape...  studio-lab-user
# 2   {'type': 'meta_lr', 'scorers': ['smape', 'mape...  studio-lab-user
# 3   {'type': 'meta_lr', 'scorers': ['smape', 'mape...  studio-lab-user
# 4   {'type': 'meta_lr', 'scorers': ['smape', 'mape...  studio-lab-user
# 5   {'type': 'meta_lr', 'scorers': ['smape', 'mape...  studio-lab-user
# 6   {'type': 'meta_lr', 'scorers': ['smape', 'mape...  studio-lab-user
# 7   {'type': 'meta_lr', 'scorers': ['smape', 'mape...  studio-lab-user
# 8   {'type': 'meta_wa', 'scorers': ['mase', 'smape...  studio-lab-user
# 9   {'type': 'meta_wa', 'scorers': ['mase', 'smape...  studio-lab-user
# 10  {'type': 'meta_wa', 'scorers': ['mase', 'smape...  studio-lab-user
# 11  {'type': 'meta_wa', 'scorers': ['mase', 'smape...  studio-lab-user
# 12  {'type': 'meta_wa', 'scorers': ['mase', 'smape...  studio-lab-user
# 13  {'type': 'meta_wa', 'scorers': ['mase', 'smape...  studio-lab-user
#
#            time  response     type  \
# 0     65.887619       200  meta_lr
# 1   1156.983846       200  meta_lr
# 2    275.278771       200  meta_lr
# 3    105.654048       200  meta_lr
# 4     12.695486       200  meta_lr
# 5    228.408271       200  meta_lr
# 6      4.940552       200  meta_lr
# 7     13.911756       200  meta_lr
# 8    124.595380       200  meta_wa
# 9    236.713296       200  meta_wa
# 10   425.591252       200  meta_wa
# 11   351.685782       200  meta_wa
# 12   337.166843       200  meta_wa
# 13   358.119383       200  meta_wa
#
#                                               metrics  \
# 0   [{'type': 'smape', 'value': 4.667966174549589}...
# 1   [{'type': 'smape', 'value': 200.0}, {'type': '...
# 2   [{'type': 'smape', 'value': 200.0}, {'type': '...
# 3   [{'type': 'smape', 'value': 200.0}, {'type': '...
# 4   [{'type': 'smape', 'value': 178.41811091755022...
# 5   [{'type': 'smape', 'value': 199.99982946699566...
# 6   [{'type': 'smape', 'value': 38.12746439829832}...
# 7   [{'type': 'smape', 'value': 199.99999677569406...
# 8   [{'type': 'mase', 'value': 1.3431122299893605}...
# 9   [{'type': 'mase', 'value': 0.8107361150541684}...
# 10  [{'type': 'mase', 'value': 3.2043658395515218}...
# 11  [{'type': 'mase', 'value': 15.75924537769056},...
# 12  [{'type': 'mase', 'value': 11.588277224010945}...
# 13  [{'type': 'mase', 'value': 4.928702326157349},...
#
#                                                 model  \
# 0   AgEBCNHWAADQ1gAAUXcAABgAAABMdwAASg4AAD+AAGVsaZ...
# 1   AgEBCPQYcwAAABAAvUxHADAAAACatg4A9bkBALXbHQBiih...
# 2   AgEBCJJFMAAAABAAGWQlAOBjHgCjng8AtkUAACAAAACSRQ...
# 3   AgEBCC2dBQAonQUAXqcDABgAAABVpwMAkmgAAD+AAGVsaZ...
# 4   AgEBCJOtAACQrQAAU4UAABgAAABMhQAAuxAAAD+AAGVsaZ...
# 5   AgEBCI6TMwAAABAA7uofAAu8DwBdiBUAspMDACAAAACOkw...
# 6   AgEBCEcMAQBADAEAW6UAABgAAABQpQAAFRcAAD+AAGVsaZ...
# 7   AgEBCFM2AgBQNgIA3m8BABgAAADXbwEA3C0AAD+AAGVsaZ...
# 8   AgEBCExYDABIWAwAp9QJABgAAACf1AkAuDwBAD+AAGVsaZ...
# 9   AgEBCP9oHwAAABAALAMbABgAAADvXw0As7ABAD+AAGVsaZ...
# 10  AgEBCOPFGwAAABAAMgwXABgAAACS4QwAjKABAD+AAGVsaZ...
# 11  AgEBCJndGwAAABAAsQQXABgAAAAc1AwAZJwBAD+AAGVsaZ...
# 12  AgEBCGqoGwAAABAAFgsXABgAAABj9AwANKABAD+AAGVsaZ...
# 13  AgEBCO8OHAAAABAAr0YXABgAAAAO3wwA8Z0BAD+AAGVsaZ...
#
#                                             test_data  \
# 0   [['1960-06-01', 535.0], ['1960-07-01', 622.0],...
# 1   [['2014-12-31 17:00:00', 9.0], ['2014-12-31 18...
# 2   [['2014-12-31 20:30:00', 3.8734], ['2014-12-31...
# 3   [['2022-12-01', 0.84], ['2023-01-01', 0.87], [...
# 4   [['2006', 0.66], ['2007', 0.65], ['2008', 0.55...
# 5   [['2017-07-04 23:30:00', 43.6], ['2017-07-04 2...
# 6   [['2015-11-01', 444507.0], ['2015-12-01', 5182...
# 7   [['2002-06-01', -0.0727656666666666], ['2002-0...
# 8   [['2015-11-01', 444507.0], ['2015-12-01', 5182...
# 9   [['2002-06-01', -0.0727656666666666], ['2002-0...
# 10  [['2019-02-28', 101.9729], ['2019-03-31', 103....
# 11  [['2019-02-28', 114.7969], ['2019-03-31', 114....
# 12  [['2019-02-28', 108.4955], ['2019-03-31', 107....
# 13  [['2019-02-28', 105.2961], ['2019-03-31', 105....
#
#                                         forecast_data
# 0   [['1960-05-31T00:00:00', 536.6447784284949], [...
# 1   [['2014-12-31T17:00:00', 244.06093488531084], ...
# 2   [['2014-12-31T20:30:00', -502.8264662468482], ...
# 3   [['2022-12-02T00:00:00', -236716.56937655865],...
# 4   [['2006-01-02T00:00:00', 89717453190.78818], [...
# 5   [['2017-07-04T23:30:00', -47712.19258963689], ...
# 6   [['2015-10-31T00:00:00', 538812.0810625734], [...
# 7   [['2002-05-31T00:00:00', 2855912.2869539745], ...
# 8   [['2015-11-01', 440535.40927294065], ['2015-12...
# 9   [['2002-06-01', -0.0051766621132544955], ['200...
# 10  [['2019-02-28', 100.22488677617763], ['2019-03...
# 11  [['2019-02-28', 113.58359305210246], ['2019-03...
# 12  [['2019-02-28', 106.80137312298976], ['2019-03...
# 13  [['2019-02-28', 104.23735029667486], ['2019-03...

# %%
from ast import literal_eval

# %%
# Comparison of the results
for idx, row in log_df.iterrows():
    comparison_df = pd.DataFrame({'test':list(np.array(literal_eval(row['test_data']))[:,1]),
                'pred':list(np.array(literal_eval(row['forecast_data']))[:,1])})
    display(comparison_df)
# Out:
#     test                pred
# 0  535.0   536.6447784284949
# 1  622.0   624.7126156353609
# 2  606.0   640.3087357562652
# 3  508.0   528.9142194897604
# 4  461.0   470.3129232763376
# 5  390.0  425.80237944609354
# 6  432.0  472.80518427899443
#    test                pred
# 0   9.0  244.06093488531084
# 1  10.0  244.48628522951086
# 2   8.0  244.63454529401204
# 3  10.0   244.8708786939524
# 4  10.0   245.1138124924792
# 5   8.0  245.36014990794823
# 6  12.0  245.59873940475293
#      test                 pred
# 0  3.8734   -502.8264662468482
# 1  3.7916  -502.33406549895517
# 2  3.7248  -502.07583139561393
# 3  3.7619   -501.8132927970073
# 4  3.8094   -501.6797112133754
# 5  4.1359   -501.5344886645544
# 6   4.217    -501.457731425804
#    test                 pred
# 0  0.84  -236716.56937655865
# 1  0.87  -236716.75797421113
# 2   1.0  -236717.21293754713
# 3  1.23   -236717.3857011199
# 4  0.98  -236717.53365027648
# 5  0.96  -236717.61220792425
# 6  1.05   -236717.4635986198
#    test               pred
# 0  0.66  89717453190.78818
# 1  0.65  89717453191.64856
# 2  0.55  89717453192.40302
# 3  0.66   89717453192.7938
# 4  0.73  89717453191.89508
# 5  0.62  89717453192.43274
# 6  0.66   89717453192.7128
#    test                 pred
# 0  43.6   -47712.19258963689
# 1  43.3  -47582.104079052806
# 2  42.8   -47554.03632862121
# 3  43.0   -47452.84592115879
# 4  42.1  -47441.376500979066
# 5  42.1   -47433.12783724442
# 6  41.4   -47400.16464453563
#        test               pred
# 0  444507.0  538812.0810625734
# 1  518253.0  554122.3903617455
# 2  400928.0  535718.6125380868
# 3  413554.0  543128.8328519018
# 4  460093.0  558538.4791210323
# 5  450935.0  539992.9729526193
# 6  471421.0    547443.67965084
#                   test                pred
# 0  -0.0727656666666666  2855912.2869539745
# 1            -0.075387   2855912.291698833
# 2   0.0057109999999999  2855912.2750650393
# 3  -0.1103773333333333  2855912.3082263693
# 4   0.0872823333333333   2855912.297117535
# 5             0.057994    2855912.28504902
# 6  -0.0598256666666666  2855912.2891600262
#        test                pred
# 0  444507.0  440535.40927294065
# 1  518253.0   444225.8629786348
# 2  400928.0   436376.0214338422
# 3  413554.0  438063.51394634123
# 4  460093.0  444285.99912602775
# 5  450935.0  439743.63831874175
# 6  471421.0  443734.42301238235
#                   test                    pred
# 0  -0.0727656666666666  -0.0051766621132544955
# 1            -0.075387   -0.003121618321107687
# 2   0.0057109999999999    0.008952509657922079
# 3  -0.1103773333333333   -0.015887152324758104
# 4   0.0872823333333333   0.0017865356998722033
# 5             0.057994  -0.0028449161600057017
# 6  -0.0598256666666666  -0.0009535623808827082
#        test                pred
# 0  101.9729  100.22488677617763
# 1  103.2309  100.97632436017685
# 2  100.9801  101.04775115235509
# 3  101.1794  101.07354799866387
# 4  101.4176  100.94843797345348
# 5  101.5514  101.01802786888923
# 6  101.8472  101.09479615135082
#        test                pred
# 0  114.7969  113.58359305210246
# 1    114.46  113.96570873841269
# 2  114.7893  114.03209610781323
# 3  114.6911  114.08126879199833
# 4  114.4141  114.11668889515323
# 5  114.2963  114.12719139888448
# 6  115.2718  114.17139902205956
#        test                pred
# 0  108.4955  106.80137312298976
# 1  107.9445  107.16871747951427
# 2  107.4001  107.15616449296186
# 3  107.2815  107.12695235107472
# 4  107.7241  107.07659542512644
# 5  107.2339  107.00914574279945
# 6  107.9056  107.02468748241502
#        test                pred
# 0  105.2961  104.23735029667486
# 1  105.2392  104.74988780770006
# 2  104.3399  104.89906941204042
# 3   104.462   104.8024484340046
# 4  105.0892  104.94673295041696
# 5   104.678  105.12352027742897
# 6  105.2156  105.04018159113797
