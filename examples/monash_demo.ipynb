# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import zipfile
import os

# %%
# URL of the page containing the table
url = "https://forecastingdata.org/"

# Send a GET request to fetch the page content
response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')

# Locate the table containing the datasets
table = soup.find_all('table')[0]  # Assuming the first table is the target

# Extract table headers
headers = [th.text.strip() for th in table.find_all('th')]
headers.append('Download Links')

# Extract table rows
rows = []
for row in table.find_all('tr')[1:]:  # Skip the header row
    cols = [td.text.strip() for td in row.find_all('td')]
    download_links = [a['href'] for a in row.find_all('a', href=True)]
    cols.append(download_links)
    rows.append(cols)

# Create a pandas DataFrame
df = pd.DataFrame(rows, columns=headers)
df['Download'] = df["Download"].apply(lambda x: x.split('\n'))
df["Download Links"] = df["Download Links"].apply(lambda x: [l for l in x if 'zenodo' in l])
df = df.explode(["Download", "Download Links"]).reset_index()

# %%
df
# Out:
#     index                  Dataset     Domain No: of Series Min. Length  \
# 0       0                       M1   Multiple          1001          15
# 1       0                       M1   Multiple          1001          15
# 2       0                       M1   Multiple          1001          15
# 3       1                       M3   Multiple          3003          20
# 4       1                       M3   Multiple          3003          20
# 5       1                       M3   Multiple          3003          20
# 6       1                       M3   Multiple          3003          20
# 7       2                       M4   Multiple        100000          19
# 8       2                       M4   Multiple        100000          19
# 9       2                       M4   Multiple        100000          19
# 10      2                       M4   Multiple        100000          19
# 11      2                       M4   Multiple        100000          19
# 12      2                       M4   Multiple        100000          19
# 13      3                  Tourism    Tourism          1311          11
# 14      3                  Tourism    Tourism          1311          11
# 15      3                  Tourism    Tourism          1311          11
# 16      4                 CIF 2016    Banking            72          34
# 17      5      London Smart Meters     Energy          5560         288
# 18      5      London Smart Meters     Energy          5560         288
# 19      6  Aus. Electricity Demand     Energy             5      230736
# 20      7               Wind Farms     Energy           339        6345
# 21      7               Wind Farms     Energy           339        6345
# 22      8                 Dominick      Sales        115704          28
# 23      9                  Bitcoin   Economic            18        2659
# 24      9                  Bitcoin   Economic            18        2659
# 25     10        Pedestrian Counts  Transport            66         576
# 26     11            Vehicle Trips  Transport           329          70
# 27     11            Vehicle Trips  Transport           329          70
# 28     12             KDD Cup 2018     Nature           270        9504
# 29     12             KDD Cup 2018     Nature           270        9504
# 30     13                  Weather     Nature          3010        1332
# 31     14                      NN5    Banking           111         791
# 32     14                      NN5    Banking           111         791
# 33     14                      NN5    Banking           111         791
# 34     15              Web Traffic        Web        145063         803
# 35     15              Web Traffic        Web        145063         803
# 36     15              Web Traffic        Web        145063         803
# 37     16                    Solar     Energy           137       52560
# 38     16                    Solar     Energy           137       52560
# 39     17              Electricity     Energy           321       26304
# 40     17              Electricity     Energy           321       26304
# 41     18                Car Parts      Sales          2674          51
# 42     18                Car Parts      Sales          2674          51
# 43     19                  FRED-MD   Economic           107         728
# 44     20    San Francisco Traffic  Transport           862       17544
# 45     20    San Francisco Traffic  Transport           862       17544
# 46     21                Rideshare  Transport          2304         541
# 47     21                Rideshare  Transport          2304         541
# 48     22                 Hospital     Health           767          84
# 49     23             COVID Deaths     Nature           266         212
# 50     24         Temperature Rain     Nature         32072         725
# 51     24         Temperature Rain     Nature         32072         725
# 52     25                  Sunspot     Nature             1       73931
# 53     25                  Sunspot     Nature             1       73931
# 54     26       Saugeen River Flow     Nature             1       23741
# 55     27                US Births     Nature             1        7305
# 56     28              Solar Power     Energy             1     7397222
# 57     29               Wind Power     Energy             1     7397147
#
#    Max. Length Competition Multivariate           Download  \
# 0          150         Yes           No             Yearly
# 1          150         Yes           No          Quarterly
# 2          150         Yes           No            Monthly
# 3          144         Yes           No             Yearly
# 4          144         Yes           No          Quarterly
# 5          144         Yes           No            Monthly
# 6          144         Yes           No              Other
# 7         9933         Yes           No             Yearly
# 8         9933         Yes           No          Quarterly
# 9         9933         Yes           No            Monthly
# 10        9933         Yes           No             Weekly
# 11        9933         Yes           No              Daily
# 12        9933         Yes           No             Hourly
# 13         333         Yes           No             Yearly
# 14         333         Yes           No          Quarterly
# 15         333         Yes           No            Monthly
# 16         120         Yes           No            Monthly
# 17       39648          No           No          W Missing
# 18       39648          No           No        W/O Missing
# 19      232272          No           No        Half Hourly
# 20      527040          No           No          W Missing
# 21      527040          No           No        W/O Missing
# 22         393          No           No             Weekly
# 23        4581          No           No          W Missing
# 24        4581          No           No        W/O Missing
# 25       96424          No           No             Hourly
# 26         243          No           No          W Missing
# 27         243          No           No        W/O Missing
# 28       10920         Yes           No          W Missing
# 29       10920         Yes           No        W/O Missing
# 30       65981          No           No              Daily
# 31         791         Yes          Yes    Daily W Missing
# 32         791         Yes          Yes  Daily W/O Missing
# 33         791         Yes          Yes             Weekly
# 34         803         Yes          Yes    Daily W Missing
# 35         803         Yes          Yes  Daily W/O Missing
# 36         803         Yes          Yes             Weekly
# 37       52560          No          Yes         10 Minutes
# 38       52560          No          Yes             Weekly
# 39       26304          No          Yes             Hourly
# 40       26304          No          Yes             Weekly
# 41          51          No          Yes          W Missing
# 42          51          No          Yes        W/O Missing
# 43         728          No          Yes            Monthly
# 44       17544          No          Yes             Hourly
# 45       17544          No          Yes             Weekly
# 46         541          No          Yes          W Missing
# 47         541          No          Yes        W/O Missing
# 48          84          No          Yes            Monthly
# 49         212          No          Yes              Daily
# 50         725          No          Yes          W Missing
# 51         725          No          Yes        W/O Missing
# 52       73931          No           No          W Missing
# 53       73931          No           No        W/O Missing
# 54       23741          No           No              Daily
# 55        7305          No           No              Daily
# 56     7397222          No           No          4 Seconds
# 57     7397147          No           No          4 Seconds
#
#                             Source                     Download Links
# 0          Makridakis et al., 1982  https://zenodo.org/record/4656193
# 1          Makridakis et al., 1982  https://zenodo.org/record/4656154
# 2          Makridakis et al., 1982  https://zenodo.org/record/4656159
# 3       Makridakis and Hibon, 2000  https://zenodo.org/record/4656222
# 4       Makridakis and Hibon, 2000  https://zenodo.org/record/4656262
# 5       Makridakis and Hibon, 2000  https://zenodo.org/record/4656298
# 6       Makridakis and Hibon, 2000  https://zenodo.org/record/4656335
# 7          Makridakis et al., 2020  https://zenodo.org/record/4656379
# 8          Makridakis et al., 2020  https://zenodo.org/record/4656410
# 9          Makridakis et al., 2020  https://zenodo.org/record/4656480
# 10         Makridakis et al., 2020  https://zenodo.org/record/4656522
# 11         Makridakis et al., 2020  https://zenodo.org/record/4656548
# 12         Makridakis et al., 2020  https://zenodo.org/record/4656589
# 13     Athanasopoulos et al., 2011  https://zenodo.org/record/4656103
# 14     Athanasopoulos et al., 2011  https://zenodo.org/record/4656093
# 15     Athanasopoulos et al., 2011  https://zenodo.org/record/4656096
# 16       Stepnicka and Burda, 2017  https://zenodo.org/record/4656042
# 17               Jean-Michel, 2019  https://zenodo.org/record/4656072
# 18               Jean-Michel, 2019  https://zenodo.org/record/4656091
# 19                   Curated by us  https://zenodo.org/record/4659727
# 20                   Curated by us  https://zenodo.org/record/4654909
# 21                   Curated by us  https://zenodo.org/record/4654858
# 22     James M. Kilts Center, 2020  https://zenodo.org/record/4654802
# 23                   Curated by us  https://zenodo.org/record/5121965
# 24                   Curated by us  https://zenodo.org/record/5122101
# 25         City of Melbourne, 2020  https://zenodo.org/record/4656626
# 26           fivethirtyeight, 2015  https://zenodo.org/record/5122535
# 27           fivethirtyeight, 2015  https://zenodo.org/record/5122537
# 28                   KDD Cup, 2018  https://zenodo.org/record/4656719
# 29                   KDD Cup, 2018  https://zenodo.org/record/4656756
# 30             Sparks et al., 2020  https://zenodo.org/record/4654822
# 31          Ben Taieb et al., 2012  https://zenodo.org/record/4656110
# 32          Ben Taieb et al., 2012  https://zenodo.org/record/4656117
# 33          Ben Taieb et al., 2012  https://zenodo.org/record/4656125
# 34                    Google, 2017  https://zenodo.org/record/4656080
# 35                    Google, 2017  https://zenodo.org/record/4656075
# 36                    Google, 2017  https://zenodo.org/record/4656664
# 37                     Solar, 2020  https://zenodo.org/record/4656144
# 38                     Solar, 2020  https://zenodo.org/record/4656151
# 39                       UCI, 2020  https://zenodo.org/record/4656140
# 40                       UCI, 2020  https://zenodo.org/record/4656141
# 41                   Hyndman, 2015  https://zenodo.org/record/4656022
# 42                   Hyndman, 2015  https://zenodo.org/record/4656021
# 43          McCracken and Ng, 2016  https://zenodo.org/record/4654833
# 44                  Caltrans, 2020  https://zenodo.org/record/4656132
# 45                  Caltrans, 2020  https://zenodo.org/record/4656135
# 46                   Curated by us  https://zenodo.org/record/5122114
# 47                   Curated by us  https://zenodo.org/record/5122232
# 48                   Hyndman, 2015  https://zenodo.org/record/4656014
# 49  Johns Hopkins University, 2020  https://zenodo.org/record/4656009
# 50                   Curated by us  https://zenodo.org/record/5129073
# 51                   Curated by us  https://zenodo.org/record/5129091
# 52                   Sunspot, 2015  https://zenodo.org/record/4654773
# 53                   Sunspot, 2015  https://zenodo.org/record/4654722
# 54          McLeod and Gweon, 2013  https://zenodo.org/record/4656058
# 55              Pruim et al., 2020  https://zenodo.org/record/4656049
# 56                   Curated by us  https://zenodo.org/record/4656027
# 57                   Curated by us  https://zenodo.org/record/4656032

# %%
def download_link_extract(url):
    try:
        # Send a GET request to the page
        response = requests.get(url)
        response.raise_for_status()  # Ensure we notice bad responses
    
        # Parse the HTML content using BeautifulSoup
        soup = BeautifulSoup(response.content, "html.parser")
    
        # Find all links on the page
        links = soup.find_all('a', href=True)
    
        # Look for the specific download link based on the "download=1" parameter
        download_link = None
        for link in links:
            if "download=1" in link['href']:
                download_link = link['href']
                break
    
        if download_link:
            print("Download link found:", download_link)
            return  'https://zenodo.org' + download_link
        else:
            print("Download link not found.")
    except requests.exceptions.RequestException as e:
        print("An error occurred while making the request:", e)

# %%
df["download_link"] = df['Download Links'].apply(lambda x: download_link_extract(x))
# Out:
# Download link found: /records/4656193/files/m1_yearly_dataset.zip?download=1
# Download link found: /records/4656154/files/m1_quarterly_dataset.zip?download=1
# Download link found: /records/4656159/files/m1_monthly_dataset.zip?download=1
# Download link found: /records/4656222/files/m3_yearly_dataset.zip?download=1
# Download link found: /records/4656262/files/m3_quarterly_dataset.zip?download=1
# Download link found: /records/4656298/files/m3_monthly_dataset.zip?download=1
# Download link found: /records/4656335/files/m3_other_dataset.zip?download=1
# Download link found: /records/4656379/files/m4_yearly_dataset.zip?download=1
# Download link found: /records/4656410/files/m4_quarterly_dataset.zip?download=1
# Download link found: /records/4656480/files/m4_monthly_dataset.zip?download=1
# Download link found: /records/4656522/files/m4_weekly_dataset.zip?download=1
# Download link found: /records/4656548/files/m4_daily_dataset.zip?download=1
# Download link found: /records/4656589/files/m4_hourly_dataset.zip?download=1
# Download link found: /records/4656103/files/tourism_yearly_dataset.zip?download=1
# Download link found: /records/4656093/files/tourism_quarterly_dataset.zip?download=1
# Download link found: /records/4656096/files/tourism_monthly_dataset.zip?download=1
# Download link found: /records/4656042/files/cif_2016_dataset.zip?download=1
# Download link found: /records/4656072/files/london_smart_meters_dataset_with_missing_values.zip?download=1
# Download link found: /records/4656091/files/london_smart_meters_dataset_without_missing_values.zip?download=1
# Download link found: /records/4659727/files/australian_electricity_demand_dataset.zip?download=1
# Download link found: /records/4654909/files/wind_farms_minutely_dataset_with_missing_values.zip?download=1
# Download link found: /records/4654858/files/wind_farms_minutely_dataset_without_missing_values.zip?download=1
# Download link found: /records/4654802/files/dominick_dataset.zip?download=1
# Download link found: /records/5121965/files/bitcoin_dataset_with_missing_values.zip?download=1
# Download link found: /records/5122101/files/bitcoin_dataset_without_missing_values.zip?download=1
# Download link found: /records/4656626/files/pedestrian_counts_dataset.zip?download=1
# Download link found: /records/5122535/files/vehicle_trips_dataset_with_missing_values.zip?download=1
# Download link found: /records/5122537/files/vehicle_trips_dataset_without_missing_values.zip?download=1
# Download link found: /records/4656719/files/kdd_cup_2018_dataset_with_missing_values.zip?download=1
# Download link found: /records/4656756/files/kdd_cup_2018_dataset_without_missing_values.zip?download=1
# Download link found: /records/4654822/files/weather_dataset.zip?download=1
# Download link found: /records/4656110/files/nn5_daily_dataset_with_missing_values.zip?download=1
# Download link found: /records/4656117/files/nn5_daily_dataset_without_missing_values.zip?download=1
# Download link found: /records/4656125/files/nn5_weekly_dataset.zip?download=1
# Download link found: /records/4656080/files/kaggle_web_traffic_dataset_with_missing_values.zip?download=1
# Download link found: /records/4656075/files/kaggle_web_traffic_dataset_without_missing_values.zip?download=1
# Download link found: /records/4656664/files/kaggle_web_traffic_weekly_dataset.zip?download=1
# Download link found: /records/4656144/files/solar_10_minutes_dataset.zip?download=1
# Download link found: /records/4656151/files/solar_weekly_dataset.zip?download=1
# Download link found: /records/4656140/files/electricity_hourly_dataset.zip?download=1
# Download link found: /records/4656141/files/electricity_weekly_dataset.zip?download=1
# Download link found: /records/4656022/files/car_parts_dataset_with_missing_values.zip?download=1
# Download link found: /records/4656021/files/car_parts_dataset_without_missing_values.zip?download=1
# Download link found: /records/4654833/files/fred_md_dataset.zip?download=1
# Download link found: /records/4656132/files/traffic_hourly_dataset.zip?download=1
# Download link found: /records/4656135/files/traffic_weekly_dataset.zip?download=1
# Download link found: /records/5122114/files/rideshare_dataset_with_missing_values.zip?download=1
# Download link found: /records/5122232/files/rideshare_dataset_without_missing_values.zip?download=1
# Download link found: /records/4656014/files/hospital_dataset.zip?download=1
# Download link found: /records/4656009/files/covid_deaths_dataset.zip?download=1
# Download link found: /records/5129073/files/temperature_rain_dataset_with_missing_values.zip?download=1
# Download link found: /records/5129091/files/temperature_rain_dataset_without_missing_values.zip?download=1
# Download link found: /records/4654773/files/sunspot_dataset_with_missing_values.zip?download=1
# Download link found: /records/4654722/files/sunspot_dataset_without_missing_values.zip?download=1
# Download link found: /records/4656058/files/saugeenday_dataset.zip?download=1
# Download link found: /records/4656049/files/us_births_dataset.zip?download=1
# Download link found: /records/4656027/files/solar_4_seconds_dataset.zip?download=1
# Download link found: /records/4656032/files/wind_4_seconds_dataset.zip?download=1

# %%
def download_and_unzip(url, extract_to='.'):
    # Download the file from `url` and save it locally under `file_name`:
    local_zip_file = 'temp.zip'
    
    with requests.get(url, stream=True) as r:
        r.raise_for_status()
        with open(local_zip_file, 'wb') as f:
            for chunk in r.iter_content(chunk_size=8192):
                f.write(chunk)
    
    # Unzip the file
    with zipfile.ZipFile(local_zip_file, 'r') as zip_ref:
        zip_ref.extractall(extract_to)
    
    # Optionally remove the zip file after extraction
    os.remove(local_zip_file)

# %%
df[df['Domain'] == 'Economic']
# Out:
#     index  Dataset    Domain No: of Series Min. Length Max. Length  \
# 23      9  Bitcoin  Economic            18        2659        4581
# 24      9  Bitcoin  Economic            18        2659        4581
# 43     19  FRED-MD  Economic           107         728         728
#
#    Competition Multivariate     Download                  Source  \
# 23          No           No    W Missing           Curated by us
# 24          No           No  W/O Missing           Curated by us
# 43          No          Yes      Monthly  McCracken and Ng, 2016
#
#                        Download Links  \
# 23  https://zenodo.org/record/5121965
# 24  https://zenodo.org/record/5122101
# 43  https://zenodo.org/record/4654833
#
#                                         download_link
# 23  https://zenodo.org/records/5121965/files/bitco...
# 24  https://zenodo.org/records/5122101/files/bitco...
# 43  https://zenodo.org/records/4654833/files/fred_...

# %%
download_links = df[df['Domain'] == 'Economic']['download_link'].tolist()

# %%
for data_zip_path in download_links:
    download_and_unzip(data_zip_path, extract_to='./files')

# %%
def list_tsf_files(folder_path):
    # List all files in the given folder
    files = os.listdir(folder_path)
    # Filter out the files that end with .tsf
    tsf_files = [folder_path + '/' + f for f in files if f.endswith('.tsf')]
    return tsf_files

# %%
files = list_tsf_files('./files')

# %%
# Code snippet taking from https://github.com/rakshitha123/TSForecasting/blob/master/utils/data_loader.py
from datetime import datetime
from distutils.util import strtobool

import pandas as pd


# Converts the contents in a .tsf file into a dataframe and returns it along with other meta-data of the dataset: frequency, horizon, whether the dataset contains missing values and whether the series have equal lengths
#
# Parameters
# full_file_path_and_name - complete .tsf file path
# replace_missing_vals_with - a term to indicate the missing values in series in the returning dataframe
# value_column_name - Any name that is preferred to have as the name of the column containing series values in the returning dataframe
def convert_tsf_to_dataframe(
    full_file_path_and_name,
    replace_missing_vals_with="NaN",
    value_column_name="series_value",
):
    col_names = []
    col_types = []
    all_data = {}
    line_count = 0
    frequency = None
    forecast_horizon = None
    contain_missing_values = None
    contain_equal_length = None
    found_data_tag = False
    found_data_section = False
    started_reading_data_section = False

    with open(full_file_path_and_name, "r", encoding="cp1252") as file:
        for line in file:
            # Strip white space from start/end of line
            line = line.strip()

            if line:
                if line.startswith("@"):  # Read meta-data
                    if not line.startswith("@data"):
                        line_content = line.split(" ")
                        if line.startswith("@attribute"):
                            if (
                                len(line_content) != 3
                            ):  # Attributes have both name and type
                                raise Exception("Invalid meta-data specification.")

                            col_names.append(line_content[1])
                            col_types.append(line_content[2])
                        else:
                            if (
                                len(line_content) != 2
                            ):  # Other meta-data have only values
                                raise Exception("Invalid meta-data specification.")

                            if line.startswith("@frequency"):
                                frequency = line_content[1]
                            elif line.startswith("@horizon"):
                                forecast_horizon = int(line_content[1])
                            elif line.startswith("@missing"):
                                contain_missing_values = bool(
                                    strtobool(line_content[1])
                                )
                            elif line.startswith("@equallength"):
                                contain_equal_length = bool(strtobool(line_content[1]))

                    else:
                        if len(col_names) == 0:
                            raise Exception(
                                "Missing attribute section. Attribute section must come before data."
                            )

                        found_data_tag = True
                elif not line.startswith("#"):
                    if len(col_names) == 0:
                        raise Exception(
                            "Missing attribute section. Attribute section must come before data."
                        )
                    elif not found_data_tag:
                        raise Exception("Missing @data tag.")
                    else:
                        if not started_reading_data_section:
                            started_reading_data_section = True
                            found_data_section = True
                            all_series = []

                            for col in col_names:
                                all_data[col] = []

                        full_info = line.split(":")

                        if len(full_info) != (len(col_names) + 1):
                            raise Exception("Missing attributes/values in series.")

                        series = full_info[len(full_info) - 1]
                        series = series.split(",")

                        if len(series) == 0:
                            raise Exception(
                                "A given series should contains a set of comma separated numeric values. At least one numeric value should be there in a series. Missing values should be indicated with ? symbol"
                            )

                        numeric_series = []

                        for val in series:
                            if val == "?":
                                numeric_series.append(replace_missing_vals_with)
                            else:
                                numeric_series.append(float(val))

                        if numeric_series.count(replace_missing_vals_with) == len(
                            numeric_series
                        ):
                            raise Exception(
                                "All series values are missing. A given series should contains a set of comma separated numeric values. At least one numeric value should be there in a series."
                            )

                        all_series.append(pd.Series(numeric_series).array)

                        for i in range(len(col_names)):
                            att_val = None
                            if col_types[i] == "numeric":
                                att_val = int(full_info[i])
                            elif col_types[i] == "string":
                                att_val = str(full_info[i])
                            elif col_types[i] == "date":
                                att_val = datetime.strptime(
                                    full_info[i], "%Y-%m-%d %H-%M-%S"
                                )
                            else:
                                raise Exception(
                                    "Invalid attribute type."
                                )  # Currently, the code supports only numeric, string and date types. Extend this as required.

                            if att_val is None:
                                raise Exception("Invalid attribute value.")
                            else:
                                all_data[col_names[i]].append(att_val)

                line_count = line_count + 1

        if line_count == 0:
            raise Exception("Empty file.")
        if len(col_names) == 0:
            raise Exception("Missing attribute section.")
        if not found_data_section:
            raise Exception("Missing series information under data section.")

        all_data[value_column_name] = all_series
        loaded_data = pd.DataFrame(all_data)

        return (
            loaded_data,
            frequency,
            forecast_horizon,
            contain_missing_values,
            contain_equal_length,
        )


# Example of usage
# loaded_data, frequency, forecast_horizon, contain_missing_values, contain_equal_length = convert_tsf_to_dataframe("TSForecasting/tsf_data/sample.tsf")

# print(loaded_data)
# print(frequency)
# print(forecast_horizon)
# print(contain_missing_values)
# print(contain_equal_length)

# %%
def convert_to_pandas_frequency(frequency_str):
    # Dictionary to map units to pandas frequency codes
    unit_map = {
        'second': 'S',
        'seconds': 'S',
        'minute': 'T',
        'minutes': 'T',
        'hour': 'H',
        'hours': 'H',
        'hourly': 'H',
        'day': 'D',
        'days': 'D',
        'daily': 'D',
        'week': 'W',
        'weeks': 'W',
        'weekly': 'W',
        'month': 'M',
        'months': 'M',
        'monthly': 'M',
        'year': 'A',
        'years': 'A',
        'yearly': 'A',
        'quarter': 'Q',
        'quarters': 'Q',
        'quarterly': 'Q'
    }
    
    # Split the input string to get the number and unit
    parts = frequency_str.split('_')
    if len(parts) == 1:
        number = 1
        unit = parts[0]
        #raise ValueError("Input format should be '<number>_<unit>'")
    elif len(parts) ==2:
        number, unit = parts
        # Dict"ionary to map each unit to its half-unit equivalent
        half_unit_map = {
            'A': ('Q', 2),  # Half of a year is 2 quarters
            'Q': ('M', 2),  # Half of a quarter is 2 months
            'M': ('D', 15),  # Approximate half of a month is 15 days
            'W': ('D', 3.5),  # Half of a week is 3.5 days
            'D': ('H', 12),  # Half of a day is 12 hours
            'H': ('T', 30),  # Half of an hour is 30 minutes
            'T': ('S', 30)  # Half of a minute is 30 seconds
        }
    
        if number == 'half':
            # Get the unit key from the unit map
            unit_key = unit_map[unit]
            
            # Get the half-unit equivalent from the half_unit_map
            if unit_key in half_unit_map:
                half_unit, half_number = half_unit_map[unit_key]
                pandas_frequency = f"{int(half_number)}{half_unit}"
                return pandas_frequency
            else:
                raise ValueError(f"Half unit mapping not available for unit '{unit}'")
        else:
            try:
                number = int(number)
            except ValueError:
                raise ValueError("The number part of the input should be an integer")
    else:
        raise ValueError("Input format should be '<number>_<unit>' Maybe update unit_map")
    

    
    if unit not in unit_map:
        raise ValueError(f"Unit '{unit}' is not recognized")
    
    # Convert to pandas frequency string
    pandas_frequency = f"{number}{unit_map[unit]}"
    return pandas_frequency

# %%
def generate_timestamps(start_timestamp, frequency, values):
    # Generate a range of timestamps
    timestamps = pd.date_range(start=start_timestamp, periods=len(values), freq=convert_to_pandas_frequency(frequency))
    
    # Create a DataFrame with the values and the generated timestamps
    df = pd.DataFrame({'Timestamp': timestamps, 'Value': values})
    
    return df

# %%
df_list = []
for file in files:
    name = file.split('/')[-1].split('.tsf')[0]
    loaded_data, frequency, forecast_horizon, contain_missing_values, contain_equal_length = convert_tsf_to_dataframe(file)
    for index, row in loaded_data.iterrows():
        serie_name = name + '_' + row['series_name']
        serie = generate_timestamps(row['start_timestamp'], frequency, row['series_value'])
        df_list.append(serie)
        serie.to_csv("./files/" + serie_name + ".csv")
    os.remove(file)
# Out:
# /var/folders/np/tdfp6mp11c32fmn2ds87h7540000gn/T/ipykernel_56088/3065550573.py:3: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   timestamps = pd.date_range(start=start_timestamp, periods=len(values), freq=convert_to_pandas_frequency(frequency))

# %%
files
# Out:
# ['./files/fred_md_dataset.tsf',
#  './files/bitcoin_dataset_without_missing_values.tsf',
#  './files/bitcoin_dataset_with_missing_values.tsf']

# %%
len(df_list)
# Out:
# 143

# %%
foo = pd.read_csv("./files/m1_quarterly_dataset.tsf", sep='\t',encoding='cp1252',header=0)

# %%
foo[(~foo['# Dataset Information'].str.startswith('#'))&(~foo['# Dataset Information'].str.startswith(''))]
# Out:
#                                  # Dataset Information
# 16   T1:1975-10-01 00-00-00:0.54,0.78,0.82,0.46,0.5...
# 17   T2:1974-10-01 00-00-00:97,95,95,94,93,90,90,90...
# 18   T3:1975-10-01 00-00-00:94,132,131,127,77,103,1...
# 19   T4:1977-04-01 00-00-00:9366.37,9169.56,7776.84...
# 20   T5:1978-04-01 00-00-00:503674,549712,547329,55...
# ..                                                 ...
# 214  T199:1975-10-01 00-00-00:1184,1196,1209,1216,1...
# 215  T200:1975-10-01 00-00-00:71,50.9,40,43,51.84,4...
# 216  T201:1975-10-01 00-00-00:40.8,36.9,44.2,62.1,5...
# 217  T202:1975-10-01 00-00-00:659,660,661,673,686,6...
# 218  T203:1975-10-01 00-00-00:6.42,6.16,6.3,7.58,7....
#
# [203 rows x 1 columns]
